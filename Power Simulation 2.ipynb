# %%
import os
import optuna
import numpy as np
import pandas as pd
from time import sleep, time
from scipy.special import logit
from scipy.stats import beta
from datetime import datetime

# %%
# Generate and save inferred model if does not exist
if not os.path.isfile(f"bayesian_model/glmm.pickle"):
    os.system("python3 infer_bayesian_model.py")

# %%
def run_command_gnome(command, title="test", keep_window=False, test=False):
    if keep_window:
        command_suffix = "; $SHELL"
    else:
        command_suffix = ""
        
    if test:
        return f"""gnome-terminal --title="{title}" --command="bash -c '{command} {command_suffix}'" """
    else:
        os.system(f"""gnome-terminal --title="{title}" --command="bash -c '{command} {command_suffix}'" """)

# %% [markdown]
# ## Significance simulations

# %%
# Run simulations
def run_simulations(OA=False):
    setting_files = [os.path.isfile(f"data/{sim_name}/sim_settings_{i}.csv") for i in range(N_PROCESSES)]
    process_active = [os.path.isfile(f"data/{sim_name}/process_{i}_running") for i in range(N_PROCESSES)]
    while sum(setting_files)>0:
        for i in range(N_PROCESSES):
            if setting_files[i] and not process_active[i]:
                c = f"""python3 perform_sig_test.py --trials_per_sim {trials_per_sim} --process {i} --optimal_alloc {OA} --sim_name {sim_name}"""
                run_command_gnome(c, title=f"p{i}", keep_window=False)

        sleep(10)
        setting_files = [os.path.isfile(f"data/{sim_name}/sim_settings_{i}.csv") for i in range(N_PROCESSES)]
        process_active = [os.path.isfile(f"data/{sim_name}/process_{i}_running") for i in range(N_PROCESSES)]

# %%
# Settings for hoyle's significance testing
hoyle_total_scores = 50*26
hoyle_p_diff = 0.055
hoyle_n_raters = 38
hoyle_scores_per_r = hoyle_total_scores//hoyle_n_raters + 1

# %%
# Varying the number of raters
N_PROCESSES = 6
sim_name = "sig_n_raters"
n_sims = 1_000
trials_per_sim = 1

p_diff = hoyle_p_diff
n_raters = "(20, 150)"
scores_per_r = hoyle_scores_per_r

# Removing all produced files
if os.path.isfile(f"data/{sim_name}/sim_settings.csv"):
    os.system(f"""rm data/{sim_name}/*""")

# Generate settings file
os.system(f"""
    python3 generate_sim_settings.py --n_raters "{n_raters}" --scores_per_r {scores_per_r} \
    --n_sims {n_sims} --trials_per_sim {trials_per_sim} --sim_name {sim_name}
""")

run_simulations()
# Out:
#     p_diff=0.055, <class 'float'>
#     n_raters=(20, 150), <class 'tuple'>
#     scores_per_r=35, <class 'int'>
#     total_scores=None, <class 'NoneType'>
#     n_sims=1000, <class 'int'>
#     trials_per_sim=1
#     seed=42, <class 'int'>
#     sim_name=sig_n_raters, <class 'str'>
#     chain_method=vectorized, <class 'str'>
#     clean_dir=True, <class 'bool'>
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.

# %%
# Varying the number of raters
N_PROCESSES = 6
sim_name = "sigOA_n_raters"
n_sims = 1_000
trials_per_sim = 1

p_diff = hoyle_p_diff
n_raters = "(20, 150)"
scores_per_r = hoyle_scores_per_r

# Removing all produced files
if os.path.isfile(f"data/{sim_name}/sim_settings.csv"):
    os.system(f"""rm data/{sim_name}/*""")

# Generate settings file
os.system(f"""
    python3 generate_sim_settings.py --n_raters "{n_raters}" --scores_per_r {scores_per_r} \
    --n_sims {n_sims} --trials_per_sim {trials_per_sim} --sim_name {sim_name}
""")

run_simulations(OA=True)
# Out:
#     p_diff=0.055, <class 'float'>
#     n_raters=(20, 150), <class 'tuple'>
#     scores_per_r=35, <class 'int'>
#     total_scores=None, <class 'NoneType'>
#     n_sims=1000, <class 'int'>
#     trials_per_sim=1
#     seed=42, <class 'int'>
#     sim_name=sigOA_n_raters, <class 'str'>
#     chain_method=vectorized, <class 'str'>
#     clean_dir=True, <class 'bool'>
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.

# %%
# Varying the topics_per_r and p_diff
N_PROCESSES = 6
sim_name = "sig_p_diff"
n_sims = 1_000
trials_per_sim = 1

p_diff = "(0.04, 0.08)"
scores_per_r = hoyle_scores_per_r
total_scores = hoyle_total_scores

# Removing all produced files
if os.path.isfile(f"data/{sim_name}/sim_settings.csv"):
    os.system(f"""rm data/{sim_name}/*""")

# Generate settings file
os.system(f"""
    python3 generate_sim_settings.py --p_diff "{p_diff}" --scores_per_r "{scores_per_r}" \
    --total_scores {total_scores} --n_sims {n_sims} --trials_per_sim {trials_per_sim} \
    --sim_name {sim_name}
""")

run_simulations()
# Out:
#     p_diff=(0.04, 0.08), <class 'tuple'>
#     n_raters=None, <class 'NoneType'>
#     scores_per_r=35, <class 'int'>
#     total_scores=1300, <class 'int'>
#     n_sims=1000, <class 'int'>
#     trials_per_sim=1
#     seed=42, <class 'int'>
#     sim_name=sig_p_diff, <class 'str'>
#     chain_method=vectorized, <class 'str'>
#     clean_dir=True, <class 'bool'>
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.

# %%
# Varying the topics_per_r and p_diff
N_PROCESSES = 6
sim_name = "sigOA_p_diff"
n_sims = 1_000
trials_per_sim = 1

p_diff = "(0.04, 0.08)"
scores_per_r = hoyle_scores_per_r
total_scores = hoyle_total_scores

# Removing all produced files
if os.path.isfile(f"data/{sim_name}/sim_settings.csv"):
    os.system(f"""rm data/{sim_name}/*""")

# Generate settings file
os.system(f"""
    python3 generate_sim_settings.py --p_diff "{p_diff}" --scores_per_r "{scores_per_r}" \
    --total_scores {total_scores} --n_sims {n_sims} --trials_per_sim {trials_per_sim} \
    --sim_name {sim_name}
""")

run_simulations(OA=True)
# Out:
#     p_diff=(0.04, 0.08), <class 'tuple'>
#     n_raters=None, <class 'NoneType'>
#     scores_per_r=35, <class 'int'>
#     total_scores=1300, <class 'int'>
#     n_sims=1000, <class 'int'>
#     trials_per_sim=1
#     seed=42, <class 'int'>
#     sim_name=sigOA_p_diff, <class 'str'>
#     chain_method=vectorized, <class 'str'>
#     clean_dir=True, <class 'bool'>
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.

# %% [markdown]
# ## Power simulations

# %%
def collate_results(sim_name, test="bht", crit_val=0.05):
    try:
        df = pd.read_csv(f"data/simulations/{sim_name}.csv")
        success = (df[f"{test}_pval"] < crit_val).sum()
        fail = (df[f"{test}_pval"] >= crit_val).sum()
        return success, fail
    except FileNotFoundError:
        return 0, 0

# %%
def beta_ci(n_success, n_fail, level=0.95, l_perc=None, u_perc=None):
    a = n_success + 1
    b = n_fail+1
    if l_perc==None:
        l_perc = (1-level)/2
    if u_perc==None:
        u_perc = 1-(1-level)/2
    return beta.ppf(l_perc, a, b), beta.ppf(u_perc, a, b)

# %%
def generate_sim_settings(p_diff, n_raters, scores_per_r, total_scores, trials_per_sim=100):
    os.system(f"""
        python3 generate_sim_settings.py --p_diff "{p_diff}" --n_raters "{n_raters}" \
        --scores_per_r {scores_per_r} --total_scores {total_scores} --n_sims 1 \
        --trials_per_sim {trials_per_sim} --sim_name {sim_name}
    """)
    return()

# %%
def transfer_log(sim_name, power_id, sim_id):
    df = pd.read_csv(f"data/simulations/{sim_name}.csv")
    df.insert(0, "power_id", power_id)
    df["sim_id"] = sim_id
    
    # Overwrite file if start of a new power analysis
    if sim_id == power_id == 0:
        df.to_csv(f"data/simulations/power_{sim_name}.csv", index=False)
    else:
        log = pd.read_csv(f"data/simulations/power_{sim_name}.csv")
        pd.concat([log, df]).to_csv(f"data/simulations/power_{sim_name}.csv", index=False)
        
    return

# %%
timeout=30*60

def objective(trial):
#         Function to optimise
        n_raters = trial.suggest_int("n_raters", 30, 200)

        generate_sim_settings(p_diff, n_raters, scores_per_r, total_scores, trials_per_sim=trials_per_sim)

        # Run simulations
        setting_files = [os.path.isfile(f"data/{sim_name}/sim_settings_{i}.csv") for i in range(N_PROCESSES)]
        process_active = [os.path.isfile(f"data/{sim_name}/process_{i}_running") for i in range(N_PROCESSES)]
        n_runss = [2]*N_PROCESSES
        last_ran=[0]*N_PROCESSES
        
        while sum(setting_files)>0:
            for i in range(N_PROCESSES):
                if last_ran[i] == 0:
                    sleep(5)
                    
                if setting_files[i] and not process_active[i]:
                    source = "source ~/anaconda3/etc/profile.d/conda.sh\n"
                    conda = "conda activate bayes_topic_measures\n"
                    c = f"""python3 perform_sig_test.py --trials_per_sim {trials_per_sim} --process {i} --sim_name {sim_name} --optimal_alloc {OA} --n_runs {n_runss[i]}"""
#                     run_command_gnome(source+conda+c, title=f"p{i}", keep_window=False) # Laptop
                    run_command_gnome(c, title=f"p{i}", keep_window=False) # Desktop
                    last_ran[i] = time()
                    n_runss[i] += 3
                
                # Removing process running file if timed out
                if time() - last_ran[i] > timeout:
                    os.system(f"rm data/{sim_name}/process_{i}_running")
                    last_ran[i] = time()
                    
            sleep(10)
            
            # Calculating early termination
            n_success, n_fail = collate_results(sim_name)
            lower_ci, upper_ci = beta_ci(n_success, n_fail, level=CI_LEVEL)
            
            if 0.9 < lower_ci or upper_ci < 0.9:
                # Wait for all processes to complete
                while sum(process_active) > 0:
                    sleep(1)
                    for i in range(N_PROCESSES):
                        if time() - last_ran[i] > timeout:
                            os.system(f"rm data/{sim_name}/process_{i}_running")
                            last_ran[i] = time()
                            
                    process_active = [os.path.isfile(f"data/{sim_name}/process_{i}_running") for i in range(N_PROCESSES)]
                
                # Recalculate after waiting
                n_success, n_fail = collate_results(sim_name)
                lower_ci, upper_ci = beta_ci(n_success, n_fail, level=CI_LEVEL)
                if lower_ci < 0.9 < upper_ci:
                    continue
                
                transfer_log(sim_name, power_id, sim_id[0])
                sim_id[0] += 1
                return abs(logit(0.9) - logit((n_success+1)/(n_success+n_fail+2)))
            
            # Refresh setting and process files
            process_active = [os.path.isfile(f"data/{sim_name}/process_{i}_running") for i in range(N_PROCESSES)]
            setting_files = [os.path.isfile(f"data/{sim_name}/sim_settings_{i}.csv") for i in range(N_PROCESSES)]
        
        transfer_log(sim_name, power_id, sim_id[0])
        sim_id[0] += 1
        return abs(logit(0.9) - logit((n_success+1)/(n_success+n_fail+2)))

# %%
# Settings for hoyle's significance testing
hoyle_total_scores = 50*26
hoyle_p_diff = 0.055
hoyle_scores_per_r = 38

# %%
# Simulation settings
N_PROCESSES = 6
trials_per_sim = 120
n_sims=70

# p_diff = hoyle_p_diff
n_raters = None # Variable to be optimised by optuna 
scores_per_r = hoyle_scores_per_r
total_scores = None

# Optuna settings
CI_LEVEL = 0.91

# %%
print(datetime.now())
# Out:
# 2022-11-16 23:04:30.675322

# %%
sim_name = "power_2_045"
OA = False

power_id, p_diff = 0, 0.045
# for power_id, p_diff in enumerate(np.geomspace(0.02, 0.2, num=10)):
# list is used so that sim_id can be incremented in objective func  
sim_id = [0]
study = optuna.create_study(direction="minimize")
study.optimize(objective, n_trials=n_sims)
df = pd.DataFrame([[power_id, p_diff, study.best_trial.number,
                  study.best_params["n_raters"]]],
                  columns=["power_id", "p_diff", "best_trial", "n_raters"]) # Join power when all is complete
if power_id == 0:
    df.to_csv(f"data/simulations/optuna_log_{sim_name}.csv", index=False)
else:
    log=pd.read_csv(f"data/simulations/optuna_log_{sim_name}.csv")
    pd.concat([log, df]).to_csv(f"data/simulations/optuna_log_{sim_name}.csv", index=False)
# Out:
# [I 2022-11-16 23:04:34,165] A new study created in memory with name: no-name-4899e10c-b4c0-4e88-aaed-49cce3e31016
#     p_diff=0.045, <class 'float'>
#     n_raters=48, <class 'int'>
#     scores_per_r=38, <class 'int'>
#     total_scores=None, <class 'NoneType'>
#     n_sims=1, <class 'int'>
#     trials_per_sim=120
#     seed=42, <class 'int'>
#     sim_name=power_2_045, <class 'str'>
#     chain_method=vectorized, <class 'str'>
#     clean_dir=True, <class 'bool'>
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# [I 2022-11-16 23:08:08,571] Trial 0 finished with value: 2.1972245773362196 and parameters: {'n_raters': 48}. Best is trial 0 with value: 2.1972245773362196.
#     p_diff=0.045, <class 'float'>
#     n_raters=52, <class 'int'>
#     scores_per_r=38, <class 'int'>
#     total_scores=None, <class 'NoneType'>
#     n_sims=1, <class 'int'>
#     trials_per_sim=120
#     seed=42, <class 'int'>
#     sim_name=power_2_045, <class 'str'>
#     chain_method=vectorized, <class 'str'>
#     clean_dir=True, <class 'bool'>
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# [I 2022-11-16 23:11:11,919] Trial 1 finished with value: 2.1972245773362196 and parameters: {'n_raters': 52}. Best is trial 0 with value: 2.1972245773362196.
#     p_diff=0.045, <class 'float'>
#     n_raters=175, <class 'int'>
#     scores_per_r=38, <class 'int'>
#     total_scores=None, <class 'NoneType'>
#     n_sims=1, <class 'int'>
#     trials_per_sim=120
#     seed=42, <class 'int'>
#     sim_name=power_2_045, <class 'str'>
#     chain_method=vectorized, <class 'str'>
#     clean_dir=True, <class 'bool'>
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# [I 2022-11-16 23:30:40,725] Trial 2 finished with value: 0.23244594397652363 and parameters: {'n_raters': 175}. Best is trial 2 with value: 0.23244594397652363.
#     p_diff=0.045, <class 'float'>
#     n_raters=91, <class 'int'>
#     scores_per_r=38, <class 'int'>
#     total_scores=None, <class 'NoneType'>
#     n_sims=1, <class 'int'>
#     trials_per_sim=120
#     seed=42, <class 'int'>
#     sim_name=power_2_045, <class 'str'>
#     chain_method=vectorized, <class 'str'>
#     clean_dir=True, <class 'bool'>
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# [I 2022-11-16 23:49:56,642] Trial 3 finished with value: 1.1557707025080588 and parameters: {'n_raters': 91}. Best is trial 2 with value: 0.23244594397652363.
#     p_diff=0.045, <class 'float'>
#     n_raters=140, <class 'int'>
#     scores_per_r=38, <class 'int'>
#     total_scores=None, <class 'NoneType'>
#     n_sims=1, <class 'int'>
#     trials_per_sim=120
#     seed=42, <class 'int'>
#     sim_name=power_2_045, <class 'str'>
#     chain_method=vectorized, <class 'str'>
#     clean_dir=True, <class 'bool'>
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# [I 2022-11-17 00:09:24,038] Trial 4 finished with value: 0.6592456288842636 and parameters: {'n_raters': 140}. Best is trial 2 with value: 0.23244594397652363.
#     p_diff=0.045, <class 'float'>
#     n_raters=151, <class 'int'>
#     scores_per_r=38, <class 'int'>
#     total_scores=None, <class 'NoneType'>
#     n_sims=1, <class 'int'>
#     trials_per_sim=120
#     seed=42, <class 'int'>
#     sim_name=power_2_045, <class 'str'>
#     chain_method=vectorized, <class 'str'>
#     clean_dir=True, <class 'bool'>
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# rm: cannot remove 'data/power_2_045/process_0_running': No such file or directory
# rm: cannot remove 'data/power_2_045/process_1_running': No such file or directory
# rm: cannot remove 'data/power_2_045/process_2_running': No such file or directory
# rm: cannot remove 'data/power_2_045/process_3_running': No such file or directory
# rm: cannot remove 'data/power_2_045/process_5_running': No such file or directory
# [I 2022-11-17 01:02:20,595] Trial 5 finished with value: 0.5069345682730237 and parameters: {'n_raters': 151}. Best is trial 2 with value: 0.23244594397652363.
#     p_diff=0.045, <class 'float'>
#     n_raters=144, <class 'int'>
#     scores_per_r=38, <class 'int'>
#     total_scores=None, <class 'NoneType'>
#     n_sims=1, <class 'int'>
#     trials_per_sim=120
#     seed=42, <class 'int'>
#     sim_name=power_2_045, <class 'str'>
#     chain_method=vectorized, <class 'str'>
#     clean_dir=True, <class 'bool'>
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# [I 2022-11-17 01:19:41,753] Trial 6 finished with value: 0.7091475219063867 and parameters: {'n_raters': 144}. Best is trial 2 with value: 0.23244594397652363.
#     p_diff=0.045, <class 'float'>
#     n_raters=153, <class 'int'>
#     scores_per_r=38, <class 'int'>
#     total_scores=None, <class 'NoneType'>
#     n_sims=1, <class 'int'>
#     trials_per_sim=120
#     seed=42, <class 'int'>
#     sim_name=power_2_045, <class 'str'>
#     chain_method=vectorized, <class 'str'>
#     clean_dir=True, <class 'bool'>
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# [I 2022-11-17 01:46:21,948] Trial 7 finished with value: 0.21868920096482958 and parameters: {'n_raters': 153}. Best is trial 7 with value: 0.21868920096482958.
#     p_diff=0.045, <class 'float'>
#     n_raters=116, <class 'int'>
#     scores_per_r=38, <class 'int'>
#     total_scores=None, <class 'NoneType'>
#     n_sims=1, <class 'int'>
#     trials_per_sim=120
#     seed=42, <class 'int'>
#     sim_name=power_2_045, <class 'str'>
#     chain_method=vectorized, <class 'str'>
#     clean_dir=True, <class 'bool'>
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# [I 2022-11-17 02:11:30,679] Trial 8 finished with value: 0.44320543609101204 and parameters: {'n_raters': 116}. Best is trial 7 with value: 0.21868920096482958.
#     p_diff=0.045, <class 'float'>
#     n_raters=129, <class 'int'>
#     scores_per_r=38, <class 'int'>
#     total_scores=None, <class 'NoneType'>
#     n_sims=1, <class 'int'>
#     trials_per_sim=120
#     seed=42, <class 'int'>
#     sim_name=power_2_045, <class 'str'>
#     chain_method=vectorized, <class 'str'>
#     clean_dir=True, <class 'bool'>
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# [I 2022-11-17 02:38:00,613] Trial 9 finished with value: 0.306374205463934 and parameters: {'n_raters': 129}. Best is trial 7 with value: 0.21868920096482958.
#     p_diff=0.045, <class 'float'>
#     n_raters=198, <class 'int'>
#     scores_per_r=38, <class 'int'>
#     total_scores=None, <class 'NoneType'>
#     n_sims=1, <class 'int'>
#     trials_per_sim=120
#     seed=42, <class 'int'>
#     sim_name=power_2_045, <class 'str'>
#     chain_method=vectorized, <class 'str'>
#     clean_dir=True, <class 'bool'>
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# [I 2022-11-17 03:03:09,775] Trial 10 finished with value: 0.07082605256861285 and parameters: {'n_raters': 198}. Best is trial 10 with value: 0.07082605256861285.
#     p_diff=0.045, <class 'float'>
#     n_raters=198, <class 'int'>
#     scores_per_r=38, <class 'int'>
#     total_scores=None, <class 'NoneType'>
#     n_sims=1, <class 'int'>
#     trials_per_sim=120
#     seed=42, <class 'int'>
#     sim_name=power_2_045, <class 'str'>
#     chain_method=vectorized, <class 'str'>
#     clean_dir=True, <class 'bool'>
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# [I 2022-11-17 03:26:08,922] Trial 11 finished with value: 0.07082605256861285 and parameters: {'n_raters': 198}. Best is trial 10 with value: 0.07082605256861285.
#     p_diff=0.045, <class 'float'>
#     n_raters=199, <class 'int'>
#     scores_per_r=38, <class 'int'>
#     total_scores=None, <class 'NoneType'>
#     n_sims=1, <class 'int'>
#     trials_per_sim=120
#     seed=42, <class 'int'>
# ...
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# [I 2022-11-17 23:11:43,355] Trial 65 finished with value: 0.07082605256861285 and parameters: {'n_raters': 137}. Best is trial 21 with value: 0.018349138668196208.
#     p_diff=0.045, <class 'float'>
#     n_raters=101, <class 'int'>
#     scores_per_r=38, <class 'int'>
#     total_scores=None, <class 'NoneType'>
#     n_sims=1, <class 'int'>
#     trials_per_sim=120
#     seed=42, <class 'int'>
#     sim_name=power_2_045, <class 'str'>
#     chain_method=vectorized, <class 'str'>
#     clean_dir=True, <class 'bool'>
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# [I 2022-11-17 23:15:47,111] Trial 66 finished with value: 1.2809338454620645 and parameters: {'n_raters': 101}. Best is trial 21 with value: 0.018349138668196208.
#     p_diff=0.045, <class 'float'>
#     n_raters=167, <class 'int'>
#     scores_per_r=38, <class 'int'>
#     total_scores=None, <class 'NoneType'>
#     n_sims=1, <class 'int'>
#     trials_per_sim=120
#     seed=42, <class 'int'>
#     sim_name=power_2_045, <class 'str'>
#     chain_method=vectorized, <class 'str'>
#     clean_dir=True, <class 'bool'>
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# [I 2022-11-17 23:48:00,897] Trial 67 finished with value: 0.7646061445420891 and parameters: {'n_raters': 167}. Best is trial 21 with value: 0.018349138668196208.
#     p_diff=0.045, <class 'float'>
#     n_raters=95, <class 'int'>
#     scores_per_r=38, <class 'int'>
#     total_scores=None, <class 'NoneType'>
#     n_sims=1, <class 'int'>
#     trials_per_sim=120
#     seed=42, <class 'int'>
#     sim_name=power_2_045, <class 'str'>
#     chain_method=vectorized, <class 'str'>
#     clean_dir=True, <class 'bool'>
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# [I 2022-11-18 00:10:48,190] Trial 68 finished with value: 0.6390799592896697 and parameters: {'n_raters': 95}. Best is trial 21 with value: 0.018349138668196208.
#     p_diff=0.045, <class 'float'>
#     n_raters=109, <class 'int'>
#     scores_per_r=38, <class 'int'>
#     total_scores=None, <class 'NoneType'>
#     n_sims=1, <class 'int'>
#     trials_per_sim=120
#     seed=42, <class 'int'>
#     sim_name=power_2_045, <class 'str'>
#     chain_method=vectorized, <class 'str'>
#     clean_dir=True, <class 'bool'>
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# [I 2022-11-18 00:29:10,121] Trial 69 finished with value: 0.7548407495652854 and parameters: {'n_raters': 109}. Best is trial 21 with value: 0.018349138668196208.

# %%
sim_name = "power_2_055"
OA = False

power_id, p_diff = 0, 0.055
# for power_id, p_diff in enumerate(np.geomspace(0.02, 0.2, num=10)):
# list is used so that sim_id can be incremented in objective func  
sim_id = [0]
study = optuna.create_study(direction="minimize")
study.optimize(objective, n_trials=n_sims)
df = pd.DataFrame([[power_id, p_diff, study.best_trial.number,
                  study.best_params["n_raters"]]],
                  columns=["power_id", "p_diff", "best_trial", "n_raters"]) # Join power when all is complete
if power_id == 0:
    df.to_csv(f"data/simulations/optuna_log_{sim_name}.csv", index=False)
else:
    log=pd.read_csv(f"data/simulations/optuna_log_{sim_name}.csv")
    pd.concat([log, df]).to_csv(f"data/simulations/optuna_log_{sim_name}.csv", index=False)
# Out:
# [I 2022-11-18 00:29:10,139] A new study created in memory with name: no-name-eb3fae1c-2d17-4ba4-a7f2-6b8fbd748229
#     p_diff=0.055, <class 'float'>
#     n_raters=125, <class 'int'>
#     scores_per_r=38, <class 'int'>
#     total_scores=None, <class 'NoneType'>
#     n_sims=1, <class 'int'>
#     trials_per_sim=120
#     seed=42, <class 'int'>
#     sim_name=power_2_055, <class 'str'>
#     chain_method=vectorized, <class 'str'>
#     clean_dir=True, <class 'bool'>
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# [I 2022-11-18 01:01:08,515] Trial 0 finished with value: 0.4595323293784408 and parameters: {'n_raters': 125}. Best is trial 0 with value: 0.4595323293784408.
#     p_diff=0.055, <class 'float'>
#     n_raters=65, <class 'int'>
#     scores_per_r=38, <class 'int'>
#     total_scores=None, <class 'NoneType'>
#     n_sims=1, <class 'int'>
#     trials_per_sim=120
#     seed=42, <class 'int'>
#     sim_name=power_2_055, <class 'str'>
#     chain_method=vectorized, <class 'str'>
#     clean_dir=True, <class 'bool'>
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# [I 2022-11-18 01:23:24,859] Trial 1 finished with value: 0.7129498078561256 and parameters: {'n_raters': 65}. Best is trial 0 with value: 0.4595323293784408.
#     p_diff=0.055, <class 'float'>
#     n_raters=157, <class 'int'>
#     scores_per_r=38, <class 'int'>
#     total_scores=None, <class 'NoneType'>
#     n_sims=1, <class 'int'>
#     trials_per_sim=120
#     seed=42, <class 'int'>
#     sim_name=power_2_055, <class 'str'>
#     chain_method=vectorized, <class 'str'>
#     clean_dir=True, <class 'bool'>
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# [I 2022-11-18 01:35:08,422] Trial 2 finished with value: 1.5639755383573437 and parameters: {'n_raters': 157}. Best is trial 0 with value: 0.4595323293784408.
#     p_diff=0.055, <class 'float'>
#     n_raters=164, <class 'int'>
#     scores_per_r=38, <class 'int'>
#     total_scores=None, <class 'NoneType'>
#     n_sims=1, <class 'int'>
#     trials_per_sim=120
#     seed=42, <class 'int'>
#     sim_name=power_2_055, <class 'str'>
#     chain_method=vectorized, <class 'str'>
#     clean_dir=True, <class 'bool'>
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# [I 2022-11-18 02:00:52,781] Trial 3 finished with value: 0.21868920096482958 and parameters: {'n_raters': 164}. Best is trial 3 with value: 0.21868920096482958.
#     p_diff=0.055, <class 'float'>
#     n_raters=130, <class 'int'>
#     scores_per_r=38, <class 'int'>
#     total_scores=None, <class 'NoneType'>
#     n_sims=1, <class 'int'>
#     trials_per_sim=120
#     seed=42, <class 'int'>
#     sim_name=power_2_055, <class 'str'>
#     chain_method=vectorized, <class 'str'>
#     clean_dir=True, <class 'bool'>
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# [I 2022-11-18 02:27:35,960] Trial 4 finished with value: 0.07082605256861285 and parameters: {'n_raters': 130}. Best is trial 4 with value: 0.07082605256861285.
#     p_diff=0.055, <class 'float'>
#     n_raters=167, <class 'int'>
#     scores_per_r=38, <class 'int'>
#     total_scores=None, <class 'NoneType'>
#     n_sims=1, <class 'int'>
#     trials_per_sim=120
#     seed=42, <class 'int'>
#     sim_name=power_2_055, <class 'str'>
#     chain_method=vectorized, <class 'str'>
#     clean_dir=True, <class 'bool'>
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# [I 2022-11-18 02:51:00,082] Trial 5 finished with value: 0.6592456288842636 and parameters: {'n_raters': 167}. Best is trial 4 with value: 0.07082605256861285.
#     p_diff=0.055, <class 'float'>
#     n_raters=47, <class 'int'>
#     scores_per_r=38, <class 'int'>
#     total_scores=None, <class 'NoneType'>
#     n_sims=1, <class 'int'>
#     trials_per_sim=120
#     seed=42, <class 'int'>
#     sim_name=power_2_055, <class 'str'>
#     chain_method=vectorized, <class 'str'>
#     clean_dir=True, <class 'bool'>
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# [I 2022-11-18 03:13:58,017] Trial 6 finished with value: 1.0397717886451763 and parameters: {'n_raters': 47}. Best is trial 4 with value: 0.07082605256861285.
#     p_diff=0.055, <class 'float'>
#     n_raters=175, <class 'int'>
#     scores_per_r=38, <class 'int'>
#     total_scores=None, <class 'NoneType'>
#     n_sims=1, <class 'int'>
#     trials_per_sim=120
#     seed=42, <class 'int'>
#     sim_name=power_2_055, <class 'str'>
#     chain_method=vectorized, <class 'str'>
#     clean_dir=True, <class 'bool'>
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# [I 2022-11-18 03:35:21,873] Trial 7 finished with value: 0.893817876022097 and parameters: {'n_raters': 175}. Best is trial 4 with value: 0.07082605256861285.
#     p_diff=0.055, <class 'float'>
#     n_raters=181, <class 'int'>
#     scores_per_r=38, <class 'int'>
#     total_scores=None, <class 'NoneType'>
#     n_sims=1, <class 'int'>
#     trials_per_sim=120
#     seed=42, <class 'int'>
#     sim_name=power_2_055, <class 'str'>
#     chain_method=vectorized, <class 'str'>
#     clean_dir=True, <class 'bool'>
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# [I 2022-11-18 03:46:38,461] Trial 8 finished with value: 1.5639755383573437 and parameters: {'n_raters': 181}. Best is trial 4 with value: 0.07082605256861285.
#     p_diff=0.055, <class 'float'>
#     n_raters=89, <class 'int'>
#     scores_per_r=38, <class 'int'>
#     total_scores=None, <class 'NoneType'>
#     n_sims=1, <class 'int'>
#     trials_per_sim=120
#     seed=42, <class 'int'>
#     sim_name=power_2_055, <class 'str'>
#     chain_method=vectorized, <class 'str'>
#     clean_dir=True, <class 'bool'>
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# [I 2022-11-18 04:10:27,284] Trial 9 finished with value: 0.4595323293784408 and parameters: {'n_raters': 89}. Best is trial 4 with value: 0.07082605256861285.
#     p_diff=0.055, <class 'float'>
#     n_raters=123, <class 'int'>
#     scores_per_r=38, <class 'int'>
#     total_scores=None, <class 'NoneType'>
#     n_sims=1, <class 'int'>
#     trials_per_sim=120
#     seed=42, <class 'int'>
#     sim_name=power_2_055, <class 'str'>
#     chain_method=vectorized, <class 'str'>
#     clean_dir=True, <class 'bool'>
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# [I 2022-11-18 04:41:16,589] Trial 10 finished with value: 0.21868920096482958 and parameters: {'n_raters': 123}. Best is trial 4 with value: 0.07082605256861285.
#     p_diff=0.055, <class 'float'>
#     n_raters=138, <class 'int'>
#     scores_per_r=38, <class 'int'>
#     total_scores=None, <class 'NoneType'>
#     n_sims=1, <class 'int'>
#     trials_per_sim=120
#     seed=42, <class 'int'>
#     sim_name=power_2_055, <class 'str'>
#     chain_method=vectorized, <class 'str'>
#     clean_dir=True, <class 'bool'>
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# ...
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# [I 2022-11-19 01:33:33,471] Trial 64 finished with value: 0.11441035117774412 and parameters: {'n_raters': 100}. Best is trial 15 with value: 0.018349138668196208.
#     p_diff=0.055, <class 'float'>
#     n_raters=131, <class 'int'>
#     scores_per_r=38, <class 'int'>
#     total_scores=None, <class 'NoneType'>
#     n_sims=1, <class 'int'>
#     trials_per_sim=120
#     seed=42, <class 'int'>
#     sim_name=power_2_055, <class 'str'>
#     chain_method=vectorized, <class 'str'>
#     clean_dir=True, <class 'bool'>
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# [I 2022-11-19 01:46:38,128] Trial 65 finished with value: 1.5639755383573437 and parameters: {'n_raters': 131}. Best is trial 15 with value: 0.018349138668196208.
#     p_diff=0.055, <class 'float'>
#     n_raters=146, <class 'int'>
#     scores_per_r=38, <class 'int'>
#     total_scores=None, <class 'NoneType'>
#     n_sims=1, <class 'int'>
#     trials_per_sim=120
#     seed=42, <class 'int'>
#     sim_name=power_2_055, <class 'str'>
#     chain_method=vectorized, <class 'str'>
#     clean_dir=True, <class 'bool'>
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# [I 2022-11-19 02:21:38,691] Trial 66 finished with value: 0.601797401971718 and parameters: {'n_raters': 146}. Best is trial 15 with value: 0.018349138668196208.
#     p_diff=0.055, <class 'float'>
#     n_raters=89, <class 'int'>
#     scores_per_r=38, <class 'int'>
#     total_scores=None, <class 'NoneType'>
#     n_sims=1, <class 'int'>
#     trials_per_sim=120
#     seed=42, <class 'int'>
#     sim_name=power_2_055, <class 'str'>
#     chain_method=vectorized, <class 'str'>
#     clean_dir=True, <class 'bool'>
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# [I 2022-11-19 02:38:30,924] Trial 67 finished with value: 0.4595323293784408 and parameters: {'n_raters': 89}. Best is trial 15 with value: 0.018349138668196208.
#     p_diff=0.055, <class 'float'>
#     n_raters=49, <class 'int'>
#     scores_per_r=38, <class 'int'>
#     total_scores=None, <class 'NoneType'>
#     n_sims=1, <class 'int'>
#     trials_per_sim=120
#     seed=42, <class 'int'>
#     sim_name=power_2_055, <class 'str'>
#     chain_method=vectorized, <class 'str'>
#     clean_dir=True, <class 'bool'>
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# [I 2022-11-19 02:42:28,414] Trial 68 finished with value: 1.2809338454620645 and parameters: {'n_raters': 49}. Best is trial 15 with value: 0.018349138668196208.
#     p_diff=0.055, <class 'float'>
#     n_raters=72, <class 'int'>
#     scores_per_r=38, <class 'int'>
#     total_scores=None, <class 'NoneType'>
#     n_sims=1, <class 'int'>
#     trials_per_sim=120
#     seed=42, <class 'int'>
#     sim_name=power_2_055, <class 'str'>
#     chain_method=vectorized, <class 'str'>
#     clean_dir=True, <class 'bool'>
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# [I 2022-11-19 02:46:01,936] Trial 69 finished with value: 1.2809338454620645 and parameters: {'n_raters': 72}. Best is trial 15 with value: 0.018349138668196208.

# %%
sim_name = "power_2_070"
OA = False

power_id, p_diff = 0, 0.070
# for power_id, p_diff in enumerate(np.geomspace(0.02, 0.2, num=10)):
# list is used so that sim_id can be incremented in objective func  
sim_id = [0]
study = optuna.create_study(direction="minimize")
study.optimize(objective, n_trials=n_sims)
df = pd.DataFrame([[power_id, p_diff, study.best_trial.number,
                  study.best_params["n_raters"]]],
                  columns=["power_id", "p_diff", "best_trial", "n_raters"]) # Join power when all is complete
if power_id == 0:
    df.to_csv(f"data/simulations/optuna_log_{sim_name}.csv", index=False)
else:
    log=pd.read_csv(f"data/simulations/optuna_log_{sim_name}.csv")
    pd.concat([log, df]).to_csv(f"data/simulations/optuna_log_{sim_name}.csv", index=False)
# Out:
# [I 2022-11-19 02:46:01,954] A new study created in memory with name: no-name-347a5d0b-c334-4d84-92f6-6f3b587ccde7
#     p_diff=0.07, <class 'float'>
#     n_raters=54, <class 'int'>
#     scores_per_r=38, <class 'int'>
#     total_scores=None, <class 'NoneType'>
#     n_sims=1, <class 'int'>
#     trials_per_sim=120
#     seed=42, <class 'int'>
#     sim_name=power_2_070, <class 'str'>
#     chain_method=vectorized, <class 'str'>
#     clean_dir=True, <class 'bool'>
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# [I 2022-11-19 03:20:42,568] Trial 0 finished with value: 0.33293866403990213 and parameters: {'n_raters': 54}. Best is trial 0 with value: 0.33293866403990213.
#     p_diff=0.07, <class 'float'>
#     n_raters=97, <class 'int'>
#     scores_per_r=38, <class 'int'>
#     total_scores=None, <class 'NoneType'>
#     n_sims=1, <class 'int'>
#     trials_per_sim=120
#     seed=42, <class 'int'>
#     sim_name=power_2_070, <class 'str'>
#     chain_method=vectorized, <class 'str'>
#     clean_dir=True, <class 'bool'>
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# [I 2022-11-19 03:45:31,631] Trial 1 finished with value: 0.893817876022097 and parameters: {'n_raters': 97}. Best is trial 0 with value: 0.33293866403990213.
#     p_diff=0.07, <class 'float'>
#     n_raters=56, <class 'int'>
#     scores_per_r=38, <class 'int'>
#     total_scores=None, <class 'NoneType'>
#     n_sims=1, <class 'int'>
#     trials_per_sim=120
#     seed=42, <class 'int'>
#     sim_name=power_2_070, <class 'str'>
#     chain_method=vectorized, <class 'str'>
#     clean_dir=True, <class 'bool'>
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# [I 2022-11-19 04:20:38,648] Trial 2 finished with value: 0.4595323293784408 and parameters: {'n_raters': 56}. Best is trial 0 with value: 0.33293866403990213.
#     p_diff=0.07, <class 'float'>
#     n_raters=147, <class 'int'>
#     scores_per_r=38, <class 'int'>
#     total_scores=None, <class 'NoneType'>
#     n_sims=1, <class 'int'>
#     trials_per_sim=120
#     seed=42, <class 'int'>
#     sim_name=power_2_070, <class 'str'>
#     chain_method=vectorized, <class 'str'>
#     clean_dir=True, <class 'bool'>
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# [I 2022-11-19 04:33:10,572] Trial 3 finished with value: 1.5639755383573437 and parameters: {'n_raters': 147}. Best is trial 0 with value: 0.33293866403990213.
#     p_diff=0.07, <class 'float'>
#     n_raters=163, <class 'int'>
#     scores_per_r=38, <class 'int'>
#     total_scores=None, <class 'NoneType'>
#     n_sims=1, <class 'int'>
#     trials_per_sim=120
#     seed=42, <class 'int'>
#     sim_name=power_2_070, <class 'str'>
#     chain_method=vectorized, <class 'str'>
#     clean_dir=True, <class 'bool'>
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# [I 2022-11-19 04:50:19,587] Trial 4 finished with value: 1.734601055388104 and parameters: {'n_raters': 163}. Best is trial 0 with value: 0.33293866403990213.
#     p_diff=0.07, <class 'float'>
#     n_raters=161, <class 'int'>
#     scores_per_r=38, <class 'int'>
#     total_scores=None, <class 'NoneType'>
#     n_sims=1, <class 'int'>
#     trials_per_sim=120
#     seed=42, <class 'int'>
#     sim_name=power_2_070, <class 'str'>
#     chain_method=vectorized, <class 'str'>
#     clean_dir=True, <class 'bool'>
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# [I 2022-11-19 05:16:43,006] Trial 5 finished with value: 1.1927995037278096 and parameters: {'n_raters': 161}. Best is trial 0 with value: 0.33293866403990213.
#     p_diff=0.07, <class 'float'>
#     n_raters=47, <class 'int'>
#     scores_per_r=38, <class 'int'>
#     total_scores=None, <class 'NoneType'>
#     n_sims=1, <class 'int'>
#     trials_per_sim=120
#     seed=42, <class 'int'>
#     sim_name=power_2_070, <class 'str'>
#     chain_method=vectorized, <class 'str'>
#     clean_dir=True, <class 'bool'>
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# [I 2022-11-19 05:51:05,483] Trial 6 finished with value: 0.5069345682730237 and parameters: {'n_raters': 47}. Best is trial 0 with value: 0.33293866403990213.
#     p_diff=0.07, <class 'float'>
#     n_raters=144, <class 'int'>
#     scores_per_r=38, <class 'int'>
#     total_scores=None, <class 'NoneType'>
#     n_sims=1, <class 'int'>
#     trials_per_sim=120
#     seed=42, <class 'int'>
#     sim_name=power_2_070, <class 'str'>
#     chain_method=vectorized, <class 'str'>
#     clean_dir=True, <class 'bool'>
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# [I 2022-11-19 06:14:29,992] Trial 7 finished with value: 1.09861228866811 and parameters: {'n_raters': 144}. Best is trial 0 with value: 0.33293866403990213.
#     p_diff=0.07, <class 'float'>
#     n_raters=75, <class 'int'>
#     scores_per_r=38, <class 'int'>
#     total_scores=None, <class 'NoneType'>
#     n_sims=1, <class 'int'>
#     trials_per_sim=120
#     seed=42, <class 'int'>
#     sim_name=power_2_070, <class 'str'>
#     chain_method=vectorized, <class 'str'>
#     clean_dir=True, <class 'bool'>
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# [I 2022-11-19 06:27:27,649] Trial 8 finished with value: 1.5639755383573437 and parameters: {'n_raters': 75}. Best is trial 0 with value: 0.33293866403990213.
#     p_diff=0.07, <class 'float'>
#     n_raters=41, <class 'int'>
#     scores_per_r=38, <class 'int'>
#     total_scores=None, <class 'NoneType'>
#     n_sims=1, <class 'int'>
#     trials_per_sim=120
#     seed=42, <class 'int'>
#     sim_name=power_2_070, <class 'str'>
#     chain_method=vectorized, <class 'str'>
#     clean_dir=True, <class 'bool'>
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# [I 2022-11-19 07:02:40,342] Trial 9 finished with value: 0.018349138668196208 and parameters: {'n_raters': 41}. Best is trial 9 with value: 0.018349138668196208.
#     p_diff=0.07, <class 'float'>
#     n_raters=192, <class 'int'>
#     scores_per_r=38, <class 'int'>
#     total_scores=None, <class 'NoneType'>
#     n_sims=1, <class 'int'>
#     trials_per_sim=120
#     seed=42, <class 'int'>
#     sim_name=power_2_070, <class 'str'>
#     chain_method=vectorized, <class 'str'>
#     clean_dir=True, <class 'bool'>
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# [I 2022-11-19 07:16:30,048] Trial 10 finished with value: 1.5639755383573437 and parameters: {'n_raters': 192}. Best is trial 9 with value: 0.018349138668196208.
#     p_diff=0.07, <class 'float'>
#     n_raters=31, <class 'int'>
#     scores_per_r=38, <class 'int'>
#     total_scores=None, <class 'NoneType'>
#     n_sims=1, <class 'int'>
#     trials_per_sim=120
#     seed=42, <class 'int'>
#     sim_name=power_2_070, <class 'str'>
#     chain_method=vectorized, <class 'str'>
#     clean_dir=True, <class 'bool'>
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# [I 2022-11-19 07:20:51,755] Trial 11 finished with value: 1.2809338454620645 and parameters: {'n_raters': 31}. Best is trial 9 with value: 0.018349138668196208.
#     p_diff=0.07, <class 'float'>
#     n_raters=89, <class 'int'>
#     scores_per_r=38, <class 'int'>
#     total_scores=None, <class 'NoneType'>
#     n_sims=1, <class 'int'>
#     trials_per_sim=120
#     seed=42, <class 'int'>
#     sim_name=power_2_070, <class 'str'>
#     chain_method=vectorized, <class 'str'>
#     clean_dir=True, <class 'bool'>
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# [I 2022-11-19 07:43:33,600] Trial 12 finished with value: 1.09861228866811 and parameters: {'n_raters': 89}. Best is trial 9 with value: 0.018349138668196208.
#     p_diff=0.07, <class 'float'>
#     n_raters=63, <class 'int'>
#     scores_per_r=38, <class 'int'>
#     total_scores=None, <class 'NoneType'>
#     n_sims=1, <class 'int'>
#     trials_per_sim=120
#     seed=42, <class 'int'>
#     sim_name=power_2_070, <class 'str'>
#     chain_method=vectorized, <class 'str'>
#     clean_dir=True, <class 'bool'>
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# [I 2022-11-19 08:10:10,365] Trial 13 finished with value: 0.893817876022097 and parameters: {'n_raters': 63}. Best is trial 9 with value: 0.018349138668196208.
#     p_diff=0.07, <class 'float'>
#     n_raters=111, <class 'int'>
#     scores_per_r=38, <class 'int'>
#     total_scores=None, <class 'NoneType'>
#     n_sims=1, <class 'int'>
#     trials_per_sim=120
#     seed=42, <class 'int'>
#     sim_name=power_2_070, <class 'str'>
#     chain_method=vectorized, <class 'str'>
#     clean_dir=True, <class 'bool'>
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# [I 2022-11-19 08:35:06,442] Trial 14 finished with value: 0.6592456288842636 and parameters: {'n_raters': 111}. Best is trial 9 with value: 0.018349138668196208.
#     p_diff=0.07, <class 'float'>
#     n_raters=35, <class 'int'>
#     scores_per_r=38, <class 'int'>
#     total_scores=None, <class 'NoneType'>
#     n_sims=1, <class 'int'>
#     trials_per_sim=120
#     seed=42, <class 'int'>
#     sim_name=power_2_070, <class 'str'>
#     chain_method=vectorized, <class 'str'>
#     clean_dir=True, <class 'bool'>
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# [W 2022-11-19 08:59:57,933] Trial 15 failed because of the following error: KeyboardInterrupt()
# Traceback (most recent call last):
#   File "/home/roger/.local/lib/python3.10/site-packages/optuna/study/_optimize.py", line 196, in _run_trial
#     value_or_values = func(trial)
#   File "/tmp/ipykernel_13942/621871392.py", line 34, in objective
#     sleep(10)
# KeyboardInterrupt
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In [21], line 9
#       7 sim_id = [0]
#       8 study = optuna.create_study(direction="minimize")
# ----> 9 study.optimize(objective, n_trials=n_sims)
#      10 df = pd.DataFrame([[power_id, p_diff, study.best_trial.number,
#      11                   study.best_params["n_raters"]]],
#      12                   columns=["power_id", "p_diff", "best_trial", "n_raters"]) # Join power when all is complete
#      13 if power_id == 0:
#
# File ~/.local/lib/python3.10/site-packages/optuna/study/study.py:419, in Study.optimize(self, func, n_trials, timeout, n_jobs, catch, callbacks, gc_after_trial, show_progress_bar)
#     315 def optimize(
#     316     self,
#     317     func: ObjectiveFuncType,
#    (...)
#     324     show_progress_bar: bool = False,
#     325 ) -> None:
#     326     """Optimize an objective function.
#     327
#     328     Optimization is done by choosing a suitable set of hyperparameter values from a given
#    (...)
#     416             If nested invocation of this method occurs.
#     417     """
# --> 419     _optimize(
#     420         study=self,
#     421         func=func,
#     422         n_trials=n_trials,
#     423         timeout=timeout,
#     424         n_jobs=n_jobs,
#     425         catch=catch,
#     426         callbacks=callbacks,
#     427         gc_after_trial=gc_after_trial,
#     428         show_progress_bar=show_progress_bar,
#     429     )
#
# File ~/.local/lib/python3.10/site-packages/optuna/study/_optimize.py:66, in _optimize(study, func, n_trials, timeout, n_jobs, catch, callbacks, gc_after_trial, show_progress_bar)
#      64 try:
#      65     if n_jobs == 1:
# ---> 66         _optimize_sequential(
#      67             study,
#      68             func,
#      69             n_trials,
#      70             timeout,
#      71             catch,
#      72             callbacks,
#      73             gc_after_trial,
#      74             reseed_sampler_rng=False,
#      75             time_start=None,
#      76             progress_bar=progress_bar,
#      77         )
#      78     else:
#      79         if n_jobs == -1:
#
# File ~/.local/lib/python3.10/site-packages/optuna/study/_optimize.py:160, in _optimize_sequential(study, func, n_trials, timeout, catch, callbacks, gc_after_trial, reseed_sampler_rng, time_start, progress_bar)
#     157         break
#     159 try:
# --> 160     frozen_trial = _run_trial(study, func, catch)
#     161 finally:
#     162     # The following line mitigates memory problems that can be occurred in some
#     163     # environments (e.g., services that use computing containers such as CircleCI).
#     164     # Please refer to the following PR for further details:
#     165     # https://github.com/optuna/optuna/pull/325.
#     166     if gc_after_trial:
#
# File ~/.local/lib/python3.10/site-packages/optuna/study/_optimize.py:234, in _run_trial(study, func, catch)
#     227         assert False, "Should not reach."
#     229 if (
#     230     frozen_trial.state == TrialState.FAIL
#     231     and func_err is not None
#     232     and not isinstance(func_err, catch)
#     233 ):
# --> 234     raise func_err
#     235 return frozen_trial
#
# File ~/.local/lib/python3.10/site-packages/optuna/study/_optimize.py:196, in _run_trial(study, func, catch)
#     194 with get_heartbeat_thread(trial._trial_id, study._storage):
#     195     try:
# --> 196         value_or_values = func(trial)
#     197     except exceptions.TrialPruned as e:
#     198         # TODO(mamu): Handle multi-objective cases.
#     199         state = TrialState.PRUNED
#
# Cell In [15], line 34, in objective(trial)
#      31         os.system(f"rm data/{sim_name}/process_{i}_running")
#      32         last_ran[i] = time()
# ---> 34 sleep(10)
#      36 # Calculating early termination
#      37 n_success, n_fail = collate_results(sim_name)
#
# KeyboardInterrupt:

# %%
sim_name = "power_2_OA045"
OA = True

power_id, p_diff = 0, 0.045
# for power_id, p_diff in enumerate(np.geomspace(0.02, 0.2, num=10)):
# list is used so that sim_id can be incremented in objective func  
sim_id = [0]
study = optuna.create_study(direction="minimize")
study.optimize(objective, n_trials=n_sims)
df = pd.DataFrame([[power_id, p_diff, study.best_trial.number,
                  study.best_params["n_raters"]]],
                  columns=["power_id", "p_diff", "best_trial", "n_raters"]) # Join power when all is complete
if power_id == 0:
    df.to_csv(f"data/simulations/optuna_log_{sim_name}.csv", index=False)
else:
    log=pd.read_csv(f"data/simulations/optuna_log_{sim_name}.csv")
    pd.concat([log, df]).to_csv(f"data/simulations/optuna_log_{sim_name}.csv", index=False)
# Out:
# [I 2022-11-12 10:14:28,707] A new study created in memory with name: no-name-c35496fc-1e43-480a-b8d4-ff43ce41c66e
#     p_diff=0.04, <class 'float'>
#     n_raters=125, <class 'int'>
#     scores_per_r=38, <class 'int'>
#     total_scores=None, <class 'NoneType'>
#     n_sims=1, <class 'int'>
#     trials_per_sim=100
#     seed=42, <class 'int'>
#     sim_name=power040, <class 'str'>
#     chain_method=vectorized, <class 'str'>
#     clean_dir=True, <class 'bool'>
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# [I 2022-11-12 10:21:28,888] Trial 0 finished with value: 1.3862943611198908 and parameters: {'n_raters': 125}. Best is trial 0 with value: 1.3862943611198908.
#     p_diff=0.04, <class 'float'>
#     n_raters=180, <class 'int'>
#     scores_per_r=38, <class 'int'>
#     total_scores=None, <class 'NoneType'>
#     n_sims=1, <class 'int'>
#     trials_per_sim=100
#     seed=42, <class 'int'>
#     sim_name=power040, <class 'str'>
#     chain_method=vectorized, <class 'str'>
#     clean_dir=True, <class 'bool'>
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# [I 2022-11-12 10:35:32,885] Trial 1 finished with value: 0.9315582040049435 and parameters: {'n_raters': 180}. Best is trial 1 with value: 0.9315582040049435.
#     p_diff=0.04, <class 'float'>
#     n_raters=154, <class 'int'>
#     scores_per_r=38, <class 'int'>
#     total_scores=None, <class 'NoneType'>
#     n_sims=1, <class 'int'>
#     trials_per_sim=100
#     seed=42, <class 'int'>
#     sim_name=power040, <class 'str'>
#     chain_method=vectorized, <class 'str'>
#     clean_dir=True, <class 'bool'>
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# [I 2022-11-12 10:42:09,021] Trial 2 finished with value: 1.1986957472250928 and parameters: {'n_raters': 154}. Best is trial 1 with value: 0.9315582040049435.
#     p_diff=0.04, <class 'float'>
#     n_raters=77, <class 'int'>
#     scores_per_r=38, <class 'int'>
#     total_scores=None, <class 'NoneType'>
#     n_sims=1, <class 'int'>
#     trials_per_sim=100
#     seed=42, <class 'int'>
#     sim_name=power040, <class 'str'>
#     chain_method=vectorized, <class 'str'>
#     clean_dir=True, <class 'bool'>
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# [I 2022-11-12 10:48:49,204] Trial 3 finished with value: 1.8870696490323802 and parameters: {'n_raters': 77}. Best is trial 1 with value: 0.9315582040049435.
#     p_diff=0.04, <class 'float'>
#     n_raters=64, <class 'int'>
#     scores_per_r=38, <class 'int'>
#     total_scores=None, <class 'NoneType'>
#     n_sims=1, <class 'int'>
#     trials_per_sim=100
#     seed=42, <class 'int'>
#     sim_name=power040, <class 'str'>
#     chain_method=vectorized, <class 'str'>
#     clean_dir=True, <class 'bool'>
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# [I 2022-11-12 10:55:35,911] Trial 4 finished with value: 1.5612358106162227 and parameters: {'n_raters': 64}. Best is trial 1 with value: 0.9315582040049435.
#     p_diff=0.04, <class 'float'>
#     n_raters=118, <class 'int'>
#     scores_per_r=38, <class 'int'>
#     total_scores=None, <class 'NoneType'>
#     n_sims=1, <class 'int'>
#     trials_per_sim=100
#     seed=42, <class 'int'>
#     sim_name=power040, <class 'str'>
#     chain_method=vectorized, <class 'str'>
#     clean_dir=True, <class 'bool'>
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# [I 2022-11-12 11:09:07,306] Trial 5 finished with value: 1.044545067397834 and parameters: {'n_raters': 118}. Best is trial 1 with value: 0.9315582040049435.
#     p_diff=0.04, <class 'float'>
#     n_raters=107, <class 'int'>
#     scores_per_r=38, <class 'int'>
#     total_scores=None, <class 'NoneType'>
#     n_sims=1, <class 'int'>
#     trials_per_sim=100
#     seed=42, <class 'int'>
#     sim_name=power040, <class 'str'>
#     chain_method=vectorized, <class 'str'>
#     clean_dir=True, <class 'bool'>
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# [I 2022-11-12 11:15:38,515] Trial 6 finished with value: 1.1986957472250928 and parameters: {'n_raters': 107}. Best is trial 1 with value: 0.9315582040049435.
#     p_diff=0.04, <class 'float'>
#     n_raters=129, <class 'int'>
#     scores_per_r=38, <class 'int'>
#     total_scores=None, <class 'NoneType'>
#     n_sims=1, <class 'int'>
#     trials_per_sim=100
#     seed=42, <class 'int'>
#     sim_name=power040, <class 'str'>
#     chain_method=vectorized, <class 'str'>
#     clean_dir=True, <class 'bool'>
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# [I 2022-11-12 11:37:11,344] Trial 7 finished with value: 0.8560506514967983 and parameters: {'n_raters': 129}. Best is trial 7 with value: 0.8560506514967983.
#     p_diff=0.04, <class 'float'>
#     n_raters=166, <class 'int'>
#     scores_per_r=38, <class 'int'>
#     total_scores=None, <class 'NoneType'>
#     n_sims=1, <class 'int'>
#     trials_per_sim=100
#     seed=42, <class 'int'>
#     sim_name=power040, <class 'str'>
#     chain_method=vectorized, <class 'str'>
#     clean_dir=True, <class 'bool'>
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# [I 2022-11-12 12:05:26,462] Trial 8 finished with value: 0.7055697005585027 and parameters: {'n_raters': 166}. Best is trial 8 with value: 0.7055697005585027.
#     p_diff=0.04, <class 'float'>
#     n_raters=78, <class 'int'>
#     scores_per_r=38, <class 'int'>
#     total_scores=None, <class 'NoneType'>
#     n_sims=1, <class 'int'>
#     trials_per_sim=100
#     seed=42, <class 'int'>
#     sim_name=power040, <class 'str'>
#     chain_method=vectorized, <class 'str'>
#     clean_dir=True, <class 'bool'>
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# [I 2022-11-12 12:19:04,483] Trial 9 finished with value: 1.3499267169490161 and parameters: {'n_raters': 78}. Best is trial 8 with value: 0.7055697005585027.
#     p_diff=0.04, <class 'float'>
#     n_raters=179, <class 'int'>
#     scores_per_r=38, <class 'int'>
#     total_scores=None, <class 'NoneType'>
#     n_sims=1, <class 'int'>
#     trials_per_sim=100
#     seed=42, <class 'int'>
#     sim_name=power040, <class 'str'>
#     chain_method=vectorized, <class 'str'>
#     clean_dir=True, <class 'bool'>
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# [I 2022-11-12 12:27:25,274] Trial 10 finished with value: 1.0520922730332172 and parameters: {'n_raters': 179}. Best is trial 8 with value: 0.7055697005585027.
#     p_diff=0.04, <class 'float'>
#     n_raters=146, <class 'int'>
#     scores_per_r=38, <class 'int'>
#     total_scores=None, <class 'NoneType'>
#     n_sims=1, <class 'int'>
#     trials_per_sim=100
#     seed=42, <class 'int'>
#     sim_name=power040, <class 'str'>
#     chain_method=vectorized, <class 'str'>
#     clean_dir=True, <class 'bool'>
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# [I 2022-11-12 12:48:47,446] Trial 11 finished with value: 0.7254080427781668 and parameters: {'n_raters': 146}. Best is trial 8 with value: 0.7055697005585027.
#     p_diff=0.04, <class 'float'>
#     n_raters=156, <class 'int'>
#     scores_per_r=38, <class 'int'>
#     total_scores=None, <class 'NoneType'>
#     n_sims=1, <class 'int'>
#     trials_per_sim=100
#     seed=42, <class 'int'>
#     sim_name=power040, <class 'str'>
#     chain_method=vectorized, <class 'str'>
#     clean_dir=True, <class 'bool'>
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# [I 2022-11-12 13:18:17,757] Trial 12 finished with value: 0.0842603436177396 and parameters: {'n_raters': 156}. Best is trial 12 with value: 0.0842603436177396.
#     p_diff=0.04, <class 'float'>
#     n_raters=156, <class 'int'>
#     scores_per_r=38, <class 'int'>
#     total_scores=None, <class 'NoneType'>
#     n_sims=1, <class 'int'>
#     trials_per_sim=100
#     seed=42, <class 'int'>
#     sim_name=power040, <class 'str'>
#     chain_method=vectorized, <class 'str'>
#     clean_dir=True, <class 'bool'>
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# [I 2022-11-12 13:45:39,847] Trial 13 finished with value: 0.0 and parameters: {'n_raters': 156}. Best is trial 13 with value: 0.0.
#     p_diff=0.04, <class 'float'>
#     n_raters=147, <class 'int'>
#     scores_per_r=38, <class 'int'>
#     total_scores=None, <class 'NoneType'>
#     n_sims=1, <class 'int'>
#     trials_per_sim=100
#     seed=42, <class 'int'>
#     sim_name=power040, <class 'str'>
#     chain_method=vectorized, <class 'str'>
#     clean_dir=True, <class 'bool'>
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# [I 2022-11-12 14:14:30,601] Trial 14 finished with value: 0.44802472252696046 and parameters: {'n_raters': 147}. Best is trial 13 with value: 0.0.
#     p_diff=0.04, <class 'float'>
#     n_raters=161, <class 'int'>
#     scores_per_r=38, <class 'int'>
#     total_scores=None, <class 'NoneType'>
#     n_sims=1, <class 'int'>
#     trials_per_sim=100
#     seed=42, <class 'int'>
#     sim_name=power040, <class 'str'>
#     chain_method=vectorized, <class 'str'>
#     clean_dir=True, <class 'bool'>
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# ...
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# [I 2022-11-12 22:40:29,204] Trial 46 finished with value: 1.007640510462383 and parameters: {'n_raters': 154}. Best is trial 13 with value: 0.0.
#     p_diff=0.04, <class 'float'>
#     n_raters=160, <class 'int'>
#     scores_per_r=38, <class 'int'>
#     total_scores=None, <class 'NoneType'>
#     n_sims=1, <class 'int'>
#     trials_per_sim=100
#     seed=42, <class 'int'>
#     sim_name=power040, <class 'str'>
#     chain_method=vectorized, <class 'str'>
#     clean_dir=True, <class 'bool'>
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# rm: cannot remove 'data/power040/process_0_running': No such file or directory
# rm: cannot remove 'data/power040/process_0_running': No such file or directory
# rm: cannot remove 'data/power040/process_2_running': No such file or directory
# rm: cannot remove 'data/power040/process_3_running': No such file or directory
# rm: cannot remove 'data/power040/process_0_running': No such file or directory
# rm: cannot remove 'data/power040/process_2_running': No such file or directory
# rm: cannot remove 'data/power040/process_3_running': No such file or directory
# rm: cannot remove 'data/power040/process_0_running': No such file or directory
# rm: cannot remove 'data/power040/process_2_running': No such file or directory
# rm: cannot remove 'data/power040/process_3_running': No such file or directory
# rm: cannot remove 'data/power040/process_0_running': No such file or directory
# rm: cannot remove 'data/power040/process_2_running': No such file or directory
# rm: cannot remove 'data/power040/process_3_running': No such file or directory
# rm: cannot remove 'data/power040/process_0_running': No such file or directory
# rm: cannot remove 'data/power040/process_2_running': No such file or directory
# rm: cannot remove 'data/power040/process_3_running': No such file or directory
# rm: cannot remove 'data/power040/process_0_running': No such file or directory
# rm: cannot remove 'data/power040/process_2_running': No such file or directory
# rm: cannot remove 'data/power040/process_3_running': No such file or directory
# rm: cannot remove 'data/power040/process_0_running': No such file or directory
# rm: cannot remove 'data/power040/process_2_running': No such file or directory
# rm: cannot remove 'data/power040/process_3_running': No such file or directory
# rm: cannot remove 'data/power040/process_0_running': No such file or directory
# rm: cannot remove 'data/power040/process_2_running': No such file or directory
# rm: cannot remove 'data/power040/process_3_running': No such file or directory
# rm: cannot remove 'data/power040/process_0_running': No such file or directory
# rm: cannot remove 'data/power040/process_2_running': No such file or directory
# rm: cannot remove 'data/power040/process_3_running': No such file or directory
# rm: cannot remove 'data/power040/process_0_running': No such file or directory
# rm: cannot remove 'data/power040/process_2_running': No such file or directory
# rm: cannot remove 'data/power040/process_3_running': No such file or directory
# rm: cannot remove 'data/power040/process_0_running': No such file or directory
# rm: cannot remove 'data/power040/process_2_running': No such file or directory
# rm: cannot remove 'data/power040/process_3_running': No such file or directory
# rm: cannot remove 'data/power040/process_0_running': No such file or directory
# rm: cannot remove 'data/power040/process_2_running': No such file or directory
# rm: cannot remove 'data/power040/process_3_running': No such file or directory
# rm: cannot remove 'data/power040/process_0_running': No such file or directory
# rm: cannot remove 'data/power040/process_2_running': No such file or directory
# rm: cannot remove 'data/power040/process_3_running': No such file or directory
# rm: cannot remove 'data/power040/process_0_running': No such file or directory
# rm: cannot remove 'data/power040/process_2_running': No such file or directory
# rm: cannot remove 'data/power040/process_3_running': No such file or directory
# rm: cannot remove 'data/power040/process_0_running': No such file or directory
# rm: cannot remove 'data/power040/process_2_running': No such file or directory
# rm: cannot remove 'data/power040/process_3_running': No such file or directory
# rm: cannot remove 'data/power040/process_0_running': No such file or directory
# rm: cannot remove 'data/power040/process_2_running': No such file or directory
# rm: cannot remove 'data/power040/process_3_running': No such file or directory
# rm: cannot remove 'data/power040/process_0_running': No such file or directory
# rm: cannot remove 'data/power040/process_2_running': No such file or directory
# rm: cannot remove 'data/power040/process_3_running': No such file or directory
# rm: cannot remove 'data/power040/process_0_running': No such file or directory
# rm: cannot remove 'data/power040/process_2_running': No such file or directory
# rm: cannot remove 'data/power040/process_3_running': No such file or directory
# rm: cannot remove 'data/power040/process_0_running': No such file or directory
# rm: cannot remove 'data/power040/process_2_running': No such file or directory
# rm: cannot remove 'data/power040/process_3_running': No such file or directory
# rm: cannot remove 'data/power040/process_0_running': No such file or directory
# rm: cannot remove 'data/power040/process_2_running': No such file or directory
# rm: cannot remove 'data/power040/process_3_running': No such file or directory
# rm: cannot remove 'data/power040/process_0_running': No such file or directory
# rm: cannot remove 'data/power040/process_2_running': No such file or directory
# rm: cannot remove 'data/power040/process_3_running': No such file or directory
# rm: cannot remove 'data/power040/process_0_running': No such file or directory
# rm: cannot remove 'data/power040/process_2_running': No such file or directory
# rm: cannot remove 'data/power040/process_3_running': No such file or directory
# rm: cannot remove 'data/power040/process_0_running': No such file or directory
# rm: cannot remove 'data/power040/process_2_running': No such file or directory
# rm: cannot remove 'data/power040/process_3_running': No such file or directory
# rm: cannot remove 'data/power040/process_0_running': No such file or directory
# rm: cannot remove 'data/power040/process_2_running': No such file or directory
# rm: cannot remove 'data/power040/process_3_running': No such file or directory
# rm: cannot remove 'data/power040/process_0_running': No such file or directory
# rm: cannot remove 'data/power040/process_2_running': No such file or directory
# rm: cannot remove 'data/power040/process_3_running': No such file or directory
# [I 2022-11-12 22:50:55,616] Trial 47 finished with value: 1.0271533246859648 and parameters: {'n_raters': 160}. Best is trial 13 with value: 0.0.
#     p_diff=0.04, <class 'float'>
#     n_raters=149, <class 'int'>
#     scores_per_r=38, <class 'int'>
#     total_scores=None, <class 'NoneType'>
#     n_sims=1, <class 'int'>
#     trials_per_sim=100
#     seed=42, <class 'int'>
#     sim_name=power040, <class 'str'>
#     chain_method=vectorized, <class 'str'>
#     clean_dir=True, <class 'bool'>
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# [I 2022-11-12 22:57:56,750] Trial 48 finished with value: 1.1986957472250928 and parameters: {'n_raters': 149}. Best is trial 13 with value: 0.0.
#     p_diff=0.04, <class 'float'>
#     n_raters=176, <class 'int'>
#     scores_per_r=38, <class 'int'>
#     total_scores=None, <class 'NoneType'>
#     n_sims=1, <class 'int'>
#     trials_per_sim=100
#     seed=42, <class 'int'>
#     sim_name=power040, <class 'str'>
#     chain_method=vectorized, <class 'str'>
#     clean_dir=True, <class 'bool'>
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# [I 2022-11-12 23:27:08,023] Trial 49 finished with value: 0.1823215567939549 and parameters: {'n_raters': 176}. Best is trial 13 with value: 0.0.

# %%
sim_name = "power_2_OA055"
OA = True

power_id, p_diff = 0, 0.055
# for power_id, p_diff in enumerate(np.geomspace(0.02, 0.2, num=10)):
# list is used so that sim_id can be incremented in objective func  
sim_id = [0]
study = optuna.create_study(direction="minimize")
study.optimize(objective, n_trials=n_sims)
df = pd.DataFrame([[power_id, p_diff, study.best_trial.number,
                  study.best_params["n_raters"]]],
                  columns=["power_id", "p_diff", "best_trial", "n_raters"]) # Join power when all is complete
if power_id == 0:
    df.to_csv(f"data/simulations/optuna_log_{sim_name}.csv", index=False)
else:
    log=pd.read_csv(f"data/simulations/optuna_log_{sim_name}.csv")
    pd.concat([log, df]).to_csv(f"data/simulations/optuna_log_{sim_name}.csv", index=False)
# Out:
# [I 2022-11-12 10:14:28,707] A new study created in memory with name: no-name-c35496fc-1e43-480a-b8d4-ff43ce41c66e
#     p_diff=0.04, <class 'float'>
#     n_raters=125, <class 'int'>
#     scores_per_r=38, <class 'int'>
#     total_scores=None, <class 'NoneType'>
#     n_sims=1, <class 'int'>
#     trials_per_sim=100
#     seed=42, <class 'int'>
#     sim_name=power040, <class 'str'>
#     chain_method=vectorized, <class 'str'>
#     clean_dir=True, <class 'bool'>
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# [I 2022-11-12 10:21:28,888] Trial 0 finished with value: 1.3862943611198908 and parameters: {'n_raters': 125}. Best is trial 0 with value: 1.3862943611198908.
#     p_diff=0.04, <class 'float'>
#     n_raters=180, <class 'int'>
#     scores_per_r=38, <class 'int'>
#     total_scores=None, <class 'NoneType'>
#     n_sims=1, <class 'int'>
#     trials_per_sim=100
#     seed=42, <class 'int'>
#     sim_name=power040, <class 'str'>
#     chain_method=vectorized, <class 'str'>
#     clean_dir=True, <class 'bool'>
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# [I 2022-11-12 10:35:32,885] Trial 1 finished with value: 0.9315582040049435 and parameters: {'n_raters': 180}. Best is trial 1 with value: 0.9315582040049435.
#     p_diff=0.04, <class 'float'>
#     n_raters=154, <class 'int'>
#     scores_per_r=38, <class 'int'>
#     total_scores=None, <class 'NoneType'>
#     n_sims=1, <class 'int'>
#     trials_per_sim=100
#     seed=42, <class 'int'>
#     sim_name=power040, <class 'str'>
#     chain_method=vectorized, <class 'str'>
#     clean_dir=True, <class 'bool'>
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# [I 2022-11-12 10:42:09,021] Trial 2 finished with value: 1.1986957472250928 and parameters: {'n_raters': 154}. Best is trial 1 with value: 0.9315582040049435.
#     p_diff=0.04, <class 'float'>
#     n_raters=77, <class 'int'>
#     scores_per_r=38, <class 'int'>
#     total_scores=None, <class 'NoneType'>
#     n_sims=1, <class 'int'>
#     trials_per_sim=100
#     seed=42, <class 'int'>
#     sim_name=power040, <class 'str'>
#     chain_method=vectorized, <class 'str'>
#     clean_dir=True, <class 'bool'>
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# [I 2022-11-12 10:48:49,204] Trial 3 finished with value: 1.8870696490323802 and parameters: {'n_raters': 77}. Best is trial 1 with value: 0.9315582040049435.
#     p_diff=0.04, <class 'float'>
#     n_raters=64, <class 'int'>
#     scores_per_r=38, <class 'int'>
#     total_scores=None, <class 'NoneType'>
#     n_sims=1, <class 'int'>
#     trials_per_sim=100
#     seed=42, <class 'int'>
#     sim_name=power040, <class 'str'>
#     chain_method=vectorized, <class 'str'>
#     clean_dir=True, <class 'bool'>
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# [I 2022-11-12 10:55:35,911] Trial 4 finished with value: 1.5612358106162227 and parameters: {'n_raters': 64}. Best is trial 1 with value: 0.9315582040049435.
#     p_diff=0.04, <class 'float'>
#     n_raters=118, <class 'int'>
#     scores_per_r=38, <class 'int'>
#     total_scores=None, <class 'NoneType'>
#     n_sims=1, <class 'int'>
#     trials_per_sim=100
#     seed=42, <class 'int'>
#     sim_name=power040, <class 'str'>
#     chain_method=vectorized, <class 'str'>
#     clean_dir=True, <class 'bool'>
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# [I 2022-11-12 11:09:07,306] Trial 5 finished with value: 1.044545067397834 and parameters: {'n_raters': 118}. Best is trial 1 with value: 0.9315582040049435.
#     p_diff=0.04, <class 'float'>
#     n_raters=107, <class 'int'>
#     scores_per_r=38, <class 'int'>
#     total_scores=None, <class 'NoneType'>
#     n_sims=1, <class 'int'>
#     trials_per_sim=100
#     seed=42, <class 'int'>
#     sim_name=power040, <class 'str'>
#     chain_method=vectorized, <class 'str'>
#     clean_dir=True, <class 'bool'>
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# [I 2022-11-12 11:15:38,515] Trial 6 finished with value: 1.1986957472250928 and parameters: {'n_raters': 107}. Best is trial 1 with value: 0.9315582040049435.
#     p_diff=0.04, <class 'float'>
#     n_raters=129, <class 'int'>
#     scores_per_r=38, <class 'int'>
#     total_scores=None, <class 'NoneType'>
#     n_sims=1, <class 'int'>
#     trials_per_sim=100
#     seed=42, <class 'int'>
#     sim_name=power040, <class 'str'>
#     chain_method=vectorized, <class 'str'>
#     clean_dir=True, <class 'bool'>
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# [I 2022-11-12 11:37:11,344] Trial 7 finished with value: 0.8560506514967983 and parameters: {'n_raters': 129}. Best is trial 7 with value: 0.8560506514967983.
#     p_diff=0.04, <class 'float'>
#     n_raters=166, <class 'int'>
#     scores_per_r=38, <class 'int'>
#     total_scores=None, <class 'NoneType'>
#     n_sims=1, <class 'int'>
#     trials_per_sim=100
#     seed=42, <class 'int'>
#     sim_name=power040, <class 'str'>
#     chain_method=vectorized, <class 'str'>
#     clean_dir=True, <class 'bool'>
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# [I 2022-11-12 12:05:26,462] Trial 8 finished with value: 0.7055697005585027 and parameters: {'n_raters': 166}. Best is trial 8 with value: 0.7055697005585027.
#     p_diff=0.04, <class 'float'>
#     n_raters=78, <class 'int'>
#     scores_per_r=38, <class 'int'>
#     total_scores=None, <class 'NoneType'>
#     n_sims=1, <class 'int'>
#     trials_per_sim=100
#     seed=42, <class 'int'>
#     sim_name=power040, <class 'str'>
#     chain_method=vectorized, <class 'str'>
#     clean_dir=True, <class 'bool'>
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# [I 2022-11-12 12:19:04,483] Trial 9 finished with value: 1.3499267169490161 and parameters: {'n_raters': 78}. Best is trial 8 with value: 0.7055697005585027.
#     p_diff=0.04, <class 'float'>
#     n_raters=179, <class 'int'>
#     scores_per_r=38, <class 'int'>
#     total_scores=None, <class 'NoneType'>
#     n_sims=1, <class 'int'>
#     trials_per_sim=100
#     seed=42, <class 'int'>
#     sim_name=power040, <class 'str'>
#     chain_method=vectorized, <class 'str'>
#     clean_dir=True, <class 'bool'>
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# [I 2022-11-12 12:27:25,274] Trial 10 finished with value: 1.0520922730332172 and parameters: {'n_raters': 179}. Best is trial 8 with value: 0.7055697005585027.
#     p_diff=0.04, <class 'float'>
#     n_raters=146, <class 'int'>
#     scores_per_r=38, <class 'int'>
#     total_scores=None, <class 'NoneType'>
#     n_sims=1, <class 'int'>
#     trials_per_sim=100
#     seed=42, <class 'int'>
#     sim_name=power040, <class 'str'>
#     chain_method=vectorized, <class 'str'>
#     clean_dir=True, <class 'bool'>
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# [I 2022-11-12 12:48:47,446] Trial 11 finished with value: 0.7254080427781668 and parameters: {'n_raters': 146}. Best is trial 8 with value: 0.7055697005585027.
#     p_diff=0.04, <class 'float'>
#     n_raters=156, <class 'int'>
#     scores_per_r=38, <class 'int'>
#     total_scores=None, <class 'NoneType'>
#     n_sims=1, <class 'int'>
#     trials_per_sim=100
#     seed=42, <class 'int'>
#     sim_name=power040, <class 'str'>
#     chain_method=vectorized, <class 'str'>
#     clean_dir=True, <class 'bool'>
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# [I 2022-11-12 13:18:17,757] Trial 12 finished with value: 0.0842603436177396 and parameters: {'n_raters': 156}. Best is trial 12 with value: 0.0842603436177396.
#     p_diff=0.04, <class 'float'>
#     n_raters=156, <class 'int'>
#     scores_per_r=38, <class 'int'>
#     total_scores=None, <class 'NoneType'>
#     n_sims=1, <class 'int'>
#     trials_per_sim=100
#     seed=42, <class 'int'>
#     sim_name=power040, <class 'str'>
#     chain_method=vectorized, <class 'str'>
#     clean_dir=True, <class 'bool'>
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# [I 2022-11-12 13:45:39,847] Trial 13 finished with value: 0.0 and parameters: {'n_raters': 156}. Best is trial 13 with value: 0.0.
#     p_diff=0.04, <class 'float'>
#     n_raters=147, <class 'int'>
#     scores_per_r=38, <class 'int'>
#     total_scores=None, <class 'NoneType'>
#     n_sims=1, <class 'int'>
#     trials_per_sim=100
#     seed=42, <class 'int'>
#     sim_name=power040, <class 'str'>
#     chain_method=vectorized, <class 'str'>
#     clean_dir=True, <class 'bool'>
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# [I 2022-11-12 14:14:30,601] Trial 14 finished with value: 0.44802472252696046 and parameters: {'n_raters': 147}. Best is trial 13 with value: 0.0.
#     p_diff=0.04, <class 'float'>
#     n_raters=161, <class 'int'>
#     scores_per_r=38, <class 'int'>
#     total_scores=None, <class 'NoneType'>
#     n_sims=1, <class 'int'>
#     trials_per_sim=100
#     seed=42, <class 'int'>
#     sim_name=power040, <class 'str'>
#     chain_method=vectorized, <class 'str'>
#     clean_dir=True, <class 'bool'>
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# ...
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# [I 2022-11-12 22:40:29,204] Trial 46 finished with value: 1.007640510462383 and parameters: {'n_raters': 154}. Best is trial 13 with value: 0.0.
#     p_diff=0.04, <class 'float'>
#     n_raters=160, <class 'int'>
#     scores_per_r=38, <class 'int'>
#     total_scores=None, <class 'NoneType'>
#     n_sims=1, <class 'int'>
#     trials_per_sim=100
#     seed=42, <class 'int'>
#     sim_name=power040, <class 'str'>
#     chain_method=vectorized, <class 'str'>
#     clean_dir=True, <class 'bool'>
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# rm: cannot remove 'data/power040/process_0_running': No such file or directory
# rm: cannot remove 'data/power040/process_0_running': No such file or directory
# rm: cannot remove 'data/power040/process_2_running': No such file or directory
# rm: cannot remove 'data/power040/process_3_running': No such file or directory
# rm: cannot remove 'data/power040/process_0_running': No such file or directory
# rm: cannot remove 'data/power040/process_2_running': No such file or directory
# rm: cannot remove 'data/power040/process_3_running': No such file or directory
# rm: cannot remove 'data/power040/process_0_running': No such file or directory
# rm: cannot remove 'data/power040/process_2_running': No such file or directory
# rm: cannot remove 'data/power040/process_3_running': No such file or directory
# rm: cannot remove 'data/power040/process_0_running': No such file or directory
# rm: cannot remove 'data/power040/process_2_running': No such file or directory
# rm: cannot remove 'data/power040/process_3_running': No such file or directory
# rm: cannot remove 'data/power040/process_0_running': No such file or directory
# rm: cannot remove 'data/power040/process_2_running': No such file or directory
# rm: cannot remove 'data/power040/process_3_running': No such file or directory
# rm: cannot remove 'data/power040/process_0_running': No such file or directory
# rm: cannot remove 'data/power040/process_2_running': No such file or directory
# rm: cannot remove 'data/power040/process_3_running': No such file or directory
# rm: cannot remove 'data/power040/process_0_running': No such file or directory
# rm: cannot remove 'data/power040/process_2_running': No such file or directory
# rm: cannot remove 'data/power040/process_3_running': No such file or directory
# rm: cannot remove 'data/power040/process_0_running': No such file or directory
# rm: cannot remove 'data/power040/process_2_running': No such file or directory
# rm: cannot remove 'data/power040/process_3_running': No such file or directory
# rm: cannot remove 'data/power040/process_0_running': No such file or directory
# rm: cannot remove 'data/power040/process_2_running': No such file or directory
# rm: cannot remove 'data/power040/process_3_running': No such file or directory
# rm: cannot remove 'data/power040/process_0_running': No such file or directory
# rm: cannot remove 'data/power040/process_2_running': No such file or directory
# rm: cannot remove 'data/power040/process_3_running': No such file or directory
# rm: cannot remove 'data/power040/process_0_running': No such file or directory
# rm: cannot remove 'data/power040/process_2_running': No such file or directory
# rm: cannot remove 'data/power040/process_3_running': No such file or directory
# rm: cannot remove 'data/power040/process_0_running': No such file or directory
# rm: cannot remove 'data/power040/process_2_running': No such file or directory
# rm: cannot remove 'data/power040/process_3_running': No such file or directory
# rm: cannot remove 'data/power040/process_0_running': No such file or directory
# rm: cannot remove 'data/power040/process_2_running': No such file or directory
# rm: cannot remove 'data/power040/process_3_running': No such file or directory
# rm: cannot remove 'data/power040/process_0_running': No such file or directory
# rm: cannot remove 'data/power040/process_2_running': No such file or directory
# rm: cannot remove 'data/power040/process_3_running': No such file or directory
# rm: cannot remove 'data/power040/process_0_running': No such file or directory
# rm: cannot remove 'data/power040/process_2_running': No such file or directory
# rm: cannot remove 'data/power040/process_3_running': No such file or directory
# rm: cannot remove 'data/power040/process_0_running': No such file or directory
# rm: cannot remove 'data/power040/process_2_running': No such file or directory
# rm: cannot remove 'data/power040/process_3_running': No such file or directory
# rm: cannot remove 'data/power040/process_0_running': No such file or directory
# rm: cannot remove 'data/power040/process_2_running': No such file or directory
# rm: cannot remove 'data/power040/process_3_running': No such file or directory
# rm: cannot remove 'data/power040/process_0_running': No such file or directory
# rm: cannot remove 'data/power040/process_2_running': No such file or directory
# rm: cannot remove 'data/power040/process_3_running': No such file or directory
# rm: cannot remove 'data/power040/process_0_running': No such file or directory
# rm: cannot remove 'data/power040/process_2_running': No such file or directory
# rm: cannot remove 'data/power040/process_3_running': No such file or directory
# rm: cannot remove 'data/power040/process_0_running': No such file or directory
# rm: cannot remove 'data/power040/process_2_running': No such file or directory
# rm: cannot remove 'data/power040/process_3_running': No such file or directory
# rm: cannot remove 'data/power040/process_0_running': No such file or directory
# rm: cannot remove 'data/power040/process_2_running': No such file or directory
# rm: cannot remove 'data/power040/process_3_running': No such file or directory
# rm: cannot remove 'data/power040/process_0_running': No such file or directory
# rm: cannot remove 'data/power040/process_2_running': No such file or directory
# rm: cannot remove 'data/power040/process_3_running': No such file or directory
# rm: cannot remove 'data/power040/process_0_running': No such file or directory
# rm: cannot remove 'data/power040/process_2_running': No such file or directory
# rm: cannot remove 'data/power040/process_3_running': No such file or directory
# rm: cannot remove 'data/power040/process_0_running': No such file or directory
# rm: cannot remove 'data/power040/process_2_running': No such file or directory
# rm: cannot remove 'data/power040/process_3_running': No such file or directory
# rm: cannot remove 'data/power040/process_0_running': No such file or directory
# rm: cannot remove 'data/power040/process_2_running': No such file or directory
# rm: cannot remove 'data/power040/process_3_running': No such file or directory
# [I 2022-11-12 22:50:55,616] Trial 47 finished with value: 1.0271533246859648 and parameters: {'n_raters': 160}. Best is trial 13 with value: 0.0.
#     p_diff=0.04, <class 'float'>
#     n_raters=149, <class 'int'>
#     scores_per_r=38, <class 'int'>
#     total_scores=None, <class 'NoneType'>
#     n_sims=1, <class 'int'>
#     trials_per_sim=100
#     seed=42, <class 'int'>
#     sim_name=power040, <class 'str'>
#     chain_method=vectorized, <class 'str'>
#     clean_dir=True, <class 'bool'>
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# [I 2022-11-12 22:57:56,750] Trial 48 finished with value: 1.1986957472250928 and parameters: {'n_raters': 149}. Best is trial 13 with value: 0.0.
#     p_diff=0.04, <class 'float'>
#     n_raters=176, <class 'int'>
#     scores_per_r=38, <class 'int'>
#     total_scores=None, <class 'NoneType'>
#     n_sims=1, <class 'int'>
#     trials_per_sim=100
#     seed=42, <class 'int'>
#     sim_name=power040, <class 'str'>
#     chain_method=vectorized, <class 'str'>
#     clean_dir=True, <class 'bool'>
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# [I 2022-11-12 23:27:08,023] Trial 49 finished with value: 0.1823215567939549 and parameters: {'n_raters': 176}. Best is trial 13 with value: 0.0.

# %%
sim_name = "power_2_OA070"
OA = True

power_id, p_diff = 0, 0.070
# for power_id, p_diff in enumerate(np.geomspace(0.02, 0.2, num=10)):
# list is used so that sim_id can be incremented in objective func  
sim_id = [0]
study = optuna.create_study(direction="minimize")
study.optimize(objective, n_trials=n_sims)
df = pd.DataFrame([[power_id, p_diff, study.best_trial.number,
                  study.best_params["n_raters"]]],
                  columns=["power_id", "p_diff", "best_trial", "n_raters"]) # Join power when all is complete
if power_id == 0:
    df.to_csv(f"data/simulations/optuna_log_{sim_name}.csv", index=False)
else:
    log=pd.read_csv(f"data/simulations/optuna_log_{sim_name}.csv")
    pd.concat([log, df]).to_csv(f"data/simulations/optuna_log_{sim_name}.csv", index=False)
# Out:
# [I 2022-11-12 10:14:28,707] A new study created in memory with name: no-name-c35496fc-1e43-480a-b8d4-ff43ce41c66e
#     p_diff=0.04, <class 'float'>
#     n_raters=125, <class 'int'>
#     scores_per_r=38, <class 'int'>
#     total_scores=None, <class 'NoneType'>
#     n_sims=1, <class 'int'>
#     trials_per_sim=100
#     seed=42, <class 'int'>
#     sim_name=power040, <class 'str'>
#     chain_method=vectorized, <class 'str'>
#     clean_dir=True, <class 'bool'>
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# [I 2022-11-12 10:21:28,888] Trial 0 finished with value: 1.3862943611198908 and parameters: {'n_raters': 125}. Best is trial 0 with value: 1.3862943611198908.
#     p_diff=0.04, <class 'float'>
#     n_raters=180, <class 'int'>
#     scores_per_r=38, <class 'int'>
#     total_scores=None, <class 'NoneType'>
#     n_sims=1, <class 'int'>
#     trials_per_sim=100
#     seed=42, <class 'int'>
#     sim_name=power040, <class 'str'>
#     chain_method=vectorized, <class 'str'>
#     clean_dir=True, <class 'bool'>
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# [I 2022-11-12 10:35:32,885] Trial 1 finished with value: 0.9315582040049435 and parameters: {'n_raters': 180}. Best is trial 1 with value: 0.9315582040049435.
#     p_diff=0.04, <class 'float'>
#     n_raters=154, <class 'int'>
#     scores_per_r=38, <class 'int'>
#     total_scores=None, <class 'NoneType'>
#     n_sims=1, <class 'int'>
#     trials_per_sim=100
#     seed=42, <class 'int'>
#     sim_name=power040, <class 'str'>
#     chain_method=vectorized, <class 'str'>
#     clean_dir=True, <class 'bool'>
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# [I 2022-11-12 10:42:09,021] Trial 2 finished with value: 1.1986957472250928 and parameters: {'n_raters': 154}. Best is trial 1 with value: 0.9315582040049435.
#     p_diff=0.04, <class 'float'>
#     n_raters=77, <class 'int'>
#     scores_per_r=38, <class 'int'>
#     total_scores=None, <class 'NoneType'>
#     n_sims=1, <class 'int'>
#     trials_per_sim=100
#     seed=42, <class 'int'>
#     sim_name=power040, <class 'str'>
#     chain_method=vectorized, <class 'str'>
#     clean_dir=True, <class 'bool'>
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# [I 2022-11-12 10:48:49,204] Trial 3 finished with value: 1.8870696490323802 and parameters: {'n_raters': 77}. Best is trial 1 with value: 0.9315582040049435.
#     p_diff=0.04, <class 'float'>
#     n_raters=64, <class 'int'>
#     scores_per_r=38, <class 'int'>
#     total_scores=None, <class 'NoneType'>
#     n_sims=1, <class 'int'>
#     trials_per_sim=100
#     seed=42, <class 'int'>
#     sim_name=power040, <class 'str'>
#     chain_method=vectorized, <class 'str'>
#     clean_dir=True, <class 'bool'>
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# [I 2022-11-12 10:55:35,911] Trial 4 finished with value: 1.5612358106162227 and parameters: {'n_raters': 64}. Best is trial 1 with value: 0.9315582040049435.
#     p_diff=0.04, <class 'float'>
#     n_raters=118, <class 'int'>
#     scores_per_r=38, <class 'int'>
#     total_scores=None, <class 'NoneType'>
#     n_sims=1, <class 'int'>
#     trials_per_sim=100
#     seed=42, <class 'int'>
#     sim_name=power040, <class 'str'>
#     chain_method=vectorized, <class 'str'>
#     clean_dir=True, <class 'bool'>
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# [I 2022-11-12 11:09:07,306] Trial 5 finished with value: 1.044545067397834 and parameters: {'n_raters': 118}. Best is trial 1 with value: 0.9315582040049435.
#     p_diff=0.04, <class 'float'>
#     n_raters=107, <class 'int'>
#     scores_per_r=38, <class 'int'>
#     total_scores=None, <class 'NoneType'>
#     n_sims=1, <class 'int'>
#     trials_per_sim=100
#     seed=42, <class 'int'>
#     sim_name=power040, <class 'str'>
#     chain_method=vectorized, <class 'str'>
#     clean_dir=True, <class 'bool'>
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# [I 2022-11-12 11:15:38,515] Trial 6 finished with value: 1.1986957472250928 and parameters: {'n_raters': 107}. Best is trial 1 with value: 0.9315582040049435.
#     p_diff=0.04, <class 'float'>
#     n_raters=129, <class 'int'>
#     scores_per_r=38, <class 'int'>
#     total_scores=None, <class 'NoneType'>
#     n_sims=1, <class 'int'>
#     trials_per_sim=100
#     seed=42, <class 'int'>
#     sim_name=power040, <class 'str'>
#     chain_method=vectorized, <class 'str'>
#     clean_dir=True, <class 'bool'>
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# [I 2022-11-12 11:37:11,344] Trial 7 finished with value: 0.8560506514967983 and parameters: {'n_raters': 129}. Best is trial 7 with value: 0.8560506514967983.
#     p_diff=0.04, <class 'float'>
#     n_raters=166, <class 'int'>
#     scores_per_r=38, <class 'int'>
#     total_scores=None, <class 'NoneType'>
#     n_sims=1, <class 'int'>
#     trials_per_sim=100
#     seed=42, <class 'int'>
#     sim_name=power040, <class 'str'>
#     chain_method=vectorized, <class 'str'>
#     clean_dir=True, <class 'bool'>
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# [I 2022-11-12 12:05:26,462] Trial 8 finished with value: 0.7055697005585027 and parameters: {'n_raters': 166}. Best is trial 8 with value: 0.7055697005585027.
#     p_diff=0.04, <class 'float'>
#     n_raters=78, <class 'int'>
#     scores_per_r=38, <class 'int'>
#     total_scores=None, <class 'NoneType'>
#     n_sims=1, <class 'int'>
#     trials_per_sim=100
#     seed=42, <class 'int'>
#     sim_name=power040, <class 'str'>
#     chain_method=vectorized, <class 'str'>
#     clean_dir=True, <class 'bool'>
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# [I 2022-11-12 12:19:04,483] Trial 9 finished with value: 1.3499267169490161 and parameters: {'n_raters': 78}. Best is trial 8 with value: 0.7055697005585027.
#     p_diff=0.04, <class 'float'>
#     n_raters=179, <class 'int'>
#     scores_per_r=38, <class 'int'>
#     total_scores=None, <class 'NoneType'>
#     n_sims=1, <class 'int'>
#     trials_per_sim=100
#     seed=42, <class 'int'>
#     sim_name=power040, <class 'str'>
#     chain_method=vectorized, <class 'str'>
#     clean_dir=True, <class 'bool'>
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# [I 2022-11-12 12:27:25,274] Trial 10 finished with value: 1.0520922730332172 and parameters: {'n_raters': 179}. Best is trial 8 with value: 0.7055697005585027.
#     p_diff=0.04, <class 'float'>
#     n_raters=146, <class 'int'>
#     scores_per_r=38, <class 'int'>
#     total_scores=None, <class 'NoneType'>
#     n_sims=1, <class 'int'>
#     trials_per_sim=100
#     seed=42, <class 'int'>
#     sim_name=power040, <class 'str'>
#     chain_method=vectorized, <class 'str'>
#     clean_dir=True, <class 'bool'>
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# [I 2022-11-12 12:48:47,446] Trial 11 finished with value: 0.7254080427781668 and parameters: {'n_raters': 146}. Best is trial 8 with value: 0.7055697005585027.
#     p_diff=0.04, <class 'float'>
#     n_raters=156, <class 'int'>
#     scores_per_r=38, <class 'int'>
#     total_scores=None, <class 'NoneType'>
#     n_sims=1, <class 'int'>
#     trials_per_sim=100
#     seed=42, <class 'int'>
#     sim_name=power040, <class 'str'>
#     chain_method=vectorized, <class 'str'>
#     clean_dir=True, <class 'bool'>
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# [I 2022-11-12 13:18:17,757] Trial 12 finished with value: 0.0842603436177396 and parameters: {'n_raters': 156}. Best is trial 12 with value: 0.0842603436177396.
#     p_diff=0.04, <class 'float'>
#     n_raters=156, <class 'int'>
#     scores_per_r=38, <class 'int'>
#     total_scores=None, <class 'NoneType'>
#     n_sims=1, <class 'int'>
#     trials_per_sim=100
#     seed=42, <class 'int'>
#     sim_name=power040, <class 'str'>
#     chain_method=vectorized, <class 'str'>
#     clean_dir=True, <class 'bool'>
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# [I 2022-11-12 13:45:39,847] Trial 13 finished with value: 0.0 and parameters: {'n_raters': 156}. Best is trial 13 with value: 0.0.
#     p_diff=0.04, <class 'float'>
#     n_raters=147, <class 'int'>
#     scores_per_r=38, <class 'int'>
#     total_scores=None, <class 'NoneType'>
#     n_sims=1, <class 'int'>
#     trials_per_sim=100
#     seed=42, <class 'int'>
#     sim_name=power040, <class 'str'>
#     chain_method=vectorized, <class 'str'>
#     clean_dir=True, <class 'bool'>
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# [I 2022-11-12 14:14:30,601] Trial 14 finished with value: 0.44802472252696046 and parameters: {'n_raters': 147}. Best is trial 13 with value: 0.0.
#     p_diff=0.04, <class 'float'>
#     n_raters=161, <class 'int'>
#     scores_per_r=38, <class 'int'>
#     total_scores=None, <class 'NoneType'>
#     n_sims=1, <class 'int'>
#     trials_per_sim=100
#     seed=42, <class 'int'>
#     sim_name=power040, <class 'str'>
#     chain_method=vectorized, <class 'str'>
#     clean_dir=True, <class 'bool'>
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# ...
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# [I 2022-11-12 22:40:29,204] Trial 46 finished with value: 1.007640510462383 and parameters: {'n_raters': 154}. Best is trial 13 with value: 0.0.
#     p_diff=0.04, <class 'float'>
#     n_raters=160, <class 'int'>
#     scores_per_r=38, <class 'int'>
#     total_scores=None, <class 'NoneType'>
#     n_sims=1, <class 'int'>
#     trials_per_sim=100
#     seed=42, <class 'int'>
#     sim_name=power040, <class 'str'>
#     chain_method=vectorized, <class 'str'>
#     clean_dir=True, <class 'bool'>
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# rm: cannot remove 'data/power040/process_0_running': No such file or directory
# rm: cannot remove 'data/power040/process_0_running': No such file or directory
# rm: cannot remove 'data/power040/process_2_running': No such file or directory
# rm: cannot remove 'data/power040/process_3_running': No such file or directory
# rm: cannot remove 'data/power040/process_0_running': No such file or directory
# rm: cannot remove 'data/power040/process_2_running': No such file or directory
# rm: cannot remove 'data/power040/process_3_running': No such file or directory
# rm: cannot remove 'data/power040/process_0_running': No such file or directory
# rm: cannot remove 'data/power040/process_2_running': No such file or directory
# rm: cannot remove 'data/power040/process_3_running': No such file or directory
# rm: cannot remove 'data/power040/process_0_running': No such file or directory
# rm: cannot remove 'data/power040/process_2_running': No such file or directory
# rm: cannot remove 'data/power040/process_3_running': No such file or directory
# rm: cannot remove 'data/power040/process_0_running': No such file or directory
# rm: cannot remove 'data/power040/process_2_running': No such file or directory
# rm: cannot remove 'data/power040/process_3_running': No such file or directory
# rm: cannot remove 'data/power040/process_0_running': No such file or directory
# rm: cannot remove 'data/power040/process_2_running': No such file or directory
# rm: cannot remove 'data/power040/process_3_running': No such file or directory
# rm: cannot remove 'data/power040/process_0_running': No such file or directory
# rm: cannot remove 'data/power040/process_2_running': No such file or directory
# rm: cannot remove 'data/power040/process_3_running': No such file or directory
# rm: cannot remove 'data/power040/process_0_running': No such file or directory
# rm: cannot remove 'data/power040/process_2_running': No such file or directory
# rm: cannot remove 'data/power040/process_3_running': No such file or directory
# rm: cannot remove 'data/power040/process_0_running': No such file or directory
# rm: cannot remove 'data/power040/process_2_running': No such file or directory
# rm: cannot remove 'data/power040/process_3_running': No such file or directory
# rm: cannot remove 'data/power040/process_0_running': No such file or directory
# rm: cannot remove 'data/power040/process_2_running': No such file or directory
# rm: cannot remove 'data/power040/process_3_running': No such file or directory
# rm: cannot remove 'data/power040/process_0_running': No such file or directory
# rm: cannot remove 'data/power040/process_2_running': No such file or directory
# rm: cannot remove 'data/power040/process_3_running': No such file or directory
# rm: cannot remove 'data/power040/process_0_running': No such file or directory
# rm: cannot remove 'data/power040/process_2_running': No such file or directory
# rm: cannot remove 'data/power040/process_3_running': No such file or directory
# rm: cannot remove 'data/power040/process_0_running': No such file or directory
# rm: cannot remove 'data/power040/process_2_running': No such file or directory
# rm: cannot remove 'data/power040/process_3_running': No such file or directory
# rm: cannot remove 'data/power040/process_0_running': No such file or directory
# rm: cannot remove 'data/power040/process_2_running': No such file or directory
# rm: cannot remove 'data/power040/process_3_running': No such file or directory
# rm: cannot remove 'data/power040/process_0_running': No such file or directory
# rm: cannot remove 'data/power040/process_2_running': No such file or directory
# rm: cannot remove 'data/power040/process_3_running': No such file or directory
# rm: cannot remove 'data/power040/process_0_running': No such file or directory
# rm: cannot remove 'data/power040/process_2_running': No such file or directory
# rm: cannot remove 'data/power040/process_3_running': No such file or directory
# rm: cannot remove 'data/power040/process_0_running': No such file or directory
# rm: cannot remove 'data/power040/process_2_running': No such file or directory
# rm: cannot remove 'data/power040/process_3_running': No such file or directory
# rm: cannot remove 'data/power040/process_0_running': No such file or directory
# rm: cannot remove 'data/power040/process_2_running': No such file or directory
# rm: cannot remove 'data/power040/process_3_running': No such file or directory
# rm: cannot remove 'data/power040/process_0_running': No such file or directory
# rm: cannot remove 'data/power040/process_2_running': No such file or directory
# rm: cannot remove 'data/power040/process_3_running': No such file or directory
# rm: cannot remove 'data/power040/process_0_running': No such file or directory
# rm: cannot remove 'data/power040/process_2_running': No such file or directory
# rm: cannot remove 'data/power040/process_3_running': No such file or directory
# rm: cannot remove 'data/power040/process_0_running': No such file or directory
# rm: cannot remove 'data/power040/process_2_running': No such file or directory
# rm: cannot remove 'data/power040/process_3_running': No such file or directory
# rm: cannot remove 'data/power040/process_0_running': No such file or directory
# rm: cannot remove 'data/power040/process_2_running': No such file or directory
# rm: cannot remove 'data/power040/process_3_running': No such file or directory
# rm: cannot remove 'data/power040/process_0_running': No such file or directory
# rm: cannot remove 'data/power040/process_2_running': No such file or directory
# rm: cannot remove 'data/power040/process_3_running': No such file or directory
# rm: cannot remove 'data/power040/process_0_running': No such file or directory
# rm: cannot remove 'data/power040/process_2_running': No such file or directory
# rm: cannot remove 'data/power040/process_3_running': No such file or directory
# rm: cannot remove 'data/power040/process_0_running': No such file or directory
# rm: cannot remove 'data/power040/process_2_running': No such file or directory
# rm: cannot remove 'data/power040/process_3_running': No such file or directory
# [I 2022-11-12 22:50:55,616] Trial 47 finished with value: 1.0271533246859648 and parameters: {'n_raters': 160}. Best is trial 13 with value: 0.0.
#     p_diff=0.04, <class 'float'>
#     n_raters=149, <class 'int'>
#     scores_per_r=38, <class 'int'>
#     total_scores=None, <class 'NoneType'>
#     n_sims=1, <class 'int'>
#     trials_per_sim=100
#     seed=42, <class 'int'>
#     sim_name=power040, <class 'str'>
#     chain_method=vectorized, <class 'str'>
#     clean_dir=True, <class 'bool'>
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# [I 2022-11-12 22:57:56,750] Trial 48 finished with value: 1.1986957472250928 and parameters: {'n_raters': 149}. Best is trial 13 with value: 0.0.
#     p_diff=0.04, <class 'float'>
#     n_raters=176, <class 'int'>
#     scores_per_r=38, <class 'int'>
#     total_scores=None, <class 'NoneType'>
#     n_sims=1, <class 'int'>
#     trials_per_sim=100
#     seed=42, <class 'int'>
#     sim_name=power040, <class 'str'>
#     chain_method=vectorized, <class 'str'>
#     clean_dir=True, <class 'bool'>
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# [I 2022-11-12 23:27:08,023] Trial 49 finished with value: 0.1823215567939549 and parameters: {'n_raters': 176}. Best is trial 13 with value: 0.0.

# %%
print(datetime.now())
