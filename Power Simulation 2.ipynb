# %%
import os
import optuna
import numpy as np
import pandas as pd
from time import sleep, time
from scipy.special import logit
from scipy.stats import beta
from datetime import datetime

# %%
# Generate and save inferred model if does not exist
if not os.path.isfile(f"bayesian_model/glmm.pickle"):
    os.system("python3 infer_bayesian_model.py")

# %%
def run_command_gnome(command, title="test", keep_window=False, test=False):
    if keep_window:
        command_suffix = "; $SHELL"
    else:
        command_suffix = ""
        
    if test:
        return f"""gnome-terminal --title="{title}" --command="bash -c '{command} {command_suffix}'" """
    else:
        os.system(f"""gnome-terminal --title="{title}" --command="bash -c '{command} {command_suffix}'" """)

# %% [markdown]
# ## Significance simulations

# %%
# Run simulations
def run_simulations(OA=False):
    setting_files = [os.path.isfile(f"data/{sim_name}/sim_settings_{i}.csv") for i in range(N_PROCESSES)]
    process_active = [os.path.isfile(f"data/{sim_name}/process_{i}_running") for i in range(N_PROCESSES)]
    while sum(setting_files)>0:
        for i in range(N_PROCESSES):
            if setting_files[i] and not process_active[i]:
                c = f"""python3 perform_sig_test.py --trials_per_sim {trials_per_sim} --process {i} --optimal_alloc {OA} --sim_name {sim_name}"""
                run_command_gnome(c, title=f"p{i}", keep_window=False)

        sleep(10)
        setting_files = [os.path.isfile(f"data/{sim_name}/sim_settings_{i}.csv") for i in range(N_PROCESSES)]
        process_active = [os.path.isfile(f"data/{sim_name}/process_{i}_running") for i in range(N_PROCESSES)]

# %%
# Settings for hoyle's significance testing
hoyle_total_scores = 50*26
hoyle_p_diff = 0.055
hoyle_n_raters = 38
hoyle_scores_per_r = hoyle_total_scores//hoyle_n_raters + 1

# %%
# Varying the number of raters
N_PROCESSES = 6
sim_name = "sig_n_raters"
n_sims = 1_000
trials_per_sim = 1

p_diff = hoyle_p_diff
n_raters = "(20, 150)"
scores_per_r = hoyle_scores_per_r

# Removing all produced files
if os.path.isfile(f"data/{sim_name}/sim_settings.csv"):
    os.system(f"""rm data/{sim_name}/*""")

# Generate settings file
os.system(f"""
    python3 generate_sim_settings.py --n_raters "{n_raters}" --scores_per_r {scores_per_r} \
    --n_sims {n_sims} --trials_per_sim {trials_per_sim} --sim_name {sim_name}
""")

run_simulations()
# Out:
#     p_diff=0.055, <class 'float'>
#     n_raters=(20, 150), <class 'tuple'>
#     scores_per_r=35, <class 'int'>
#     total_scores=None, <class 'NoneType'>
#     n_sims=1000, <class 'int'>
#     trials_per_sim=1
#     seed=42, <class 'int'>
#     sim_name=sig_n_raters, <class 'str'>
#     chain_method=vectorized, <class 'str'>
#     clean_dir=True, <class 'bool'>
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.

# %%
# Varying the number of raters
N_PROCESSES = 6
sim_name = "sigOA_n_raters"
n_sims = 1_000
trials_per_sim = 1

p_diff = hoyle_p_diff
n_raters = "(20, 150)"
scores_per_r = hoyle_scores_per_r

# Removing all produced files
if os.path.isfile(f"data/{sim_name}/sim_settings.csv"):
    os.system(f"""rm data/{sim_name}/*""")

# Generate settings file
os.system(f"""
    python3 generate_sim_settings.py --n_raters "{n_raters}" --scores_per_r {scores_per_r} \
    --n_sims {n_sims} --trials_per_sim {trials_per_sim} --sim_name {sim_name}
""")

run_simulations(OA=True)
# Out:
#     p_diff=0.055, <class 'float'>
#     n_raters=(20, 150), <class 'tuple'>
#     scores_per_r=35, <class 'int'>
#     total_scores=None, <class 'NoneType'>
#     n_sims=1000, <class 'int'>
#     trials_per_sim=1
#     seed=42, <class 'int'>
#     sim_name=sigOA_n_raters, <class 'str'>
#     chain_method=vectorized, <class 'str'>
#     clean_dir=True, <class 'bool'>
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.

# %%
# Varying the topics_per_r and p_diff
N_PROCESSES = 6
sim_name = "sig_p_diff"
n_sims = 1_000
trials_per_sim = 1

p_diff = "(0.04, 0.08)"
scores_per_r = hoyle_scores_per_r
total_scores = hoyle_total_scores

# Removing all produced files
if os.path.isfile(f"data/{sim_name}/sim_settings.csv"):
    os.system(f"""rm data/{sim_name}/*""")

# Generate settings file
os.system(f"""
    python3 generate_sim_settings.py --p_diff "{p_diff}" --scores_per_r "{scores_per_r}" \
    --total_scores {total_scores} --n_sims {n_sims} --trials_per_sim {trials_per_sim} \
    --sim_name {sim_name}
""")

run_simulations()
# Out:
#     p_diff=(0.04, 0.08), <class 'tuple'>
#     n_raters=None, <class 'NoneType'>
#     scores_per_r=35, <class 'int'>
#     total_scores=1300, <class 'int'>
#     n_sims=1000, <class 'int'>
#     trials_per_sim=1
#     seed=42, <class 'int'>
#     sim_name=sig_p_diff, <class 'str'>
#     chain_method=vectorized, <class 'str'>
#     clean_dir=True, <class 'bool'>
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.

# %%
# Varying the topics_per_r and p_diff
N_PROCESSES = 6
sim_name = "sigOA_p_diff"
n_sims = 1_000
trials_per_sim = 1

p_diff = "(0.04, 0.08)"
scores_per_r = hoyle_scores_per_r
total_scores = hoyle_total_scores

# Removing all produced files
if os.path.isfile(f"data/{sim_name}/sim_settings.csv"):
    os.system(f"""rm data/{sim_name}/*""")

# Generate settings file
os.system(f"""
    python3 generate_sim_settings.py --p_diff "{p_diff}" --scores_per_r "{scores_per_r}" \
    --total_scores {total_scores} --n_sims {n_sims} --trials_per_sim {trials_per_sim} \
    --sim_name {sim_name}
""")

run_simulations(OA=True)
# Out:
#     p_diff=(0.04, 0.08), <class 'tuple'>
#     n_raters=None, <class 'NoneType'>
#     scores_per_r=35, <class 'int'>
#     total_scores=1300, <class 'int'>
#     n_sims=1000, <class 'int'>
#     trials_per_sim=1
#     seed=42, <class 'int'>
#     sim_name=sigOA_p_diff, <class 'str'>
#     chain_method=vectorized, <class 'str'>
#     clean_dir=True, <class 'bool'>
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.

# %% [markdown]
# ## Power simulations

# %%
def collate_results(sim_name, test="bht", crit_val=0.05):
    try:
        df = pd.read_csv(f"data/simulations/{sim_name}.csv")
        success = (df[f"{test}_pval"] < crit_val).sum()
        fail = (df[f"{test}_pval"] >= crit_val).sum()
        return success, fail
    except FileNotFoundError:
        return 0, 0

# %%
def beta_ci(n_success, n_fail, level=0.95, l_perc=None, u_perc=None):
    a = n_success + 1
    b = n_fail+1
    if l_perc==None:
        l_perc = (1-level)/2
    if u_perc==None:
        u_perc = 1-(1-level)/2
    return beta.ppf(l_perc, a, b), beta.ppf(u_perc, a, b)

# %%
def generate_sim_settings(p_diff, n_raters, scores_per_r, total_scores, trials_per_sim=100):
    os.system(f"""
        python3 generate_sim_settings.py --p_diff "{p_diff}" --n_raters "{n_raters}" \
        --scores_per_r {scores_per_r} --total_scores {total_scores} --n_sims 1 \
        --trials_per_sim {trials_per_sim} --sim_name {sim_name}
    """)
    return()

# %%
def transfer_log(sim_name, power_id, sim_id):
    df = pd.read_csv(f"data/simulations/{sim_name}.csv")
    df.insert(0, "power_id", power_id)
    df["sim_id"] = sim_id
    
    # Overwrite file if start of a new power analysis
    if sim_id == power_id == 0:
        df.to_csv(f"data/simulations/power_{sim_name}.csv", index=False)
    else:
        log = pd.read_csv(f"data/simulations/power_{sim_name}.csv")
        pd.concat([log, df]).to_csv(f"data/simulations/power_{sim_name}.csv", index=False)
        
    return

# %%
timeout=30*60

def objective(trial):
#         Function to optimise
        n_raters = trial.suggest_int("n_raters", 30, 200)

        generate_sim_settings(p_diff, n_raters, scores_per_r, total_scores, trials_per_sim=trials_per_sim)

        # Run simulations
        setting_files = [os.path.isfile(f"data/{sim_name}/sim_settings_{i}.csv") for i in range(N_PROCESSES)]
        process_active = [os.path.isfile(f"data/{sim_name}/process_{i}_running") for i in range(N_PROCESSES)]
        n_runss = [2]*N_PROCESSES
        last_ran=[0]*N_PROCESSES
        
        while sum(setting_files)>0:
            for i in range(N_PROCESSES):
                if last_ran[i] == 0:
                    sleep(5)
                    
                if setting_files[i] and not process_active[i]:
                    source = "source ~/anaconda3/etc/profile.d/conda.sh\n"
                    conda = "conda activate bayes_topic_measures\n"
                    c = f"""python3 perform_sig_test.py --trials_per_sim {trials_per_sim} --process {i} --sim_name {sim_name} --optimal_alloc {OA} --n_runs {n_runss[i]}"""
#                     run_command_gnome(source+conda+c, title=f"p{i}", keep_window=False) # Laptop
                    run_command_gnome(c, title=f"p{i}", keep_window=False) # Desktop
                    last_ran[i] = time()
                    n_runss[i] += 3
                
                # Removing process running file if timed out
                if time() - last_ran[i] > timeout:
                    os.system(f"rm data/{sim_name}/process_{i}_running")
                    last_ran[i] = time()
                    
            sleep(10)
            
            # Calculating early termination
            n_success, n_fail = collate_results(sim_name)
            lower_ci, upper_ci = beta_ci(n_success, n_fail, level=CI_LEVEL)
            
            if 0.9 < lower_ci or upper_ci < 0.9:
                # Wait for all processes to complete
                while sum(process_active) > 0:
                    sleep(1)
                    for i in range(N_PROCESSES):
                        if time() - last_ran[i] > timeout:
                            os.system(f"rm data/{sim_name}/process_{i}_running")
                            last_ran[i] = time()
                            
                    process_active = [os.path.isfile(f"data/{sim_name}/process_{i}_running") for i in range(N_PROCESSES)]
                
                # Recalculate after waiting
                n_success, n_fail = collate_results(sim_name)
                lower_ci, upper_ci = beta_ci(n_success, n_fail, level=CI_LEVEL)
                if lower_ci < 0.9 < upper_ci:
                    continue
                
                transfer_log(sim_name, power_id, sim_id[0])
                sim_id[0] += 1
                return abs(logit(0.9) - logit((n_success+1)/(n_success+n_fail+2)))
            
            # Refresh setting and process files
            process_active = [os.path.isfile(f"data/{sim_name}/process_{i}_running") for i in range(N_PROCESSES)]
            setting_files = [os.path.isfile(f"data/{sim_name}/sim_settings_{i}.csv") for i in range(N_PROCESSES)]
        
        transfer_log(sim_name, power_id, sim_id[0])
        sim_id[0] += 1
        return abs(logit(0.9) - logit((n_success+1)/(n_success+n_fail+2)))

# %%
# Settings for hoyle's significance testing
hoyle_total_scores = 50*26
hoyle_p_diff = 0.055
hoyle_scores_per_r = 38

# %%
# Simulation settings
N_PROCESSES = 6
trials_per_sim = 120
n_sims=70

# p_diff = hoyle_p_diff
n_raters = None # Variable to be optimised by optuna 
scores_per_r = hoyle_scores_per_r
total_scores = None

# Optuna settings
CI_LEVEL = 0.91

# %%
print(datetime.now())
# Out:
# 2022-11-20 10:08:08.576620

# %%
sim_name = "power_2_045"
OA = False

power_id, p_diff = 0, 0.045
# for power_id, p_diff in enumerate(np.geomspace(0.02, 0.2, num=10)):
# list is used so that sim_id can be incremented in objective func  
sim_id = [0]
study = optuna.create_study(direction="minimize")
study.optimize(objective, n_trials=n_sims)
df = pd.DataFrame([[power_id, p_diff, study.best_trial.number,
                  study.best_params["n_raters"]]],
                  columns=["power_id", "p_diff", "best_trial", "n_raters"]) # Join power when all is complete
if power_id == 0:
    df.to_csv(f"data/simulations/optuna_log_{sim_name}.csv", index=False)
else:
    log=pd.read_csv(f"data/simulations/optuna_log_{sim_name}.csv")
    pd.concat([log, df]).to_csv(f"data/simulations/optuna_log_{sim_name}.csv", index=False)
# Out:
# [I 2022-11-16 23:04:34,165] A new study created in memory with name: no-name-4899e10c-b4c0-4e88-aaed-49cce3e31016
#     p_diff=0.045, <class 'float'>
#     n_raters=48, <class 'int'>
#     scores_per_r=38, <class 'int'>
#     total_scores=None, <class 'NoneType'>
#     n_sims=1, <class 'int'>
#     trials_per_sim=120
#     seed=42, <class 'int'>
#     sim_name=power_2_045, <class 'str'>
#     chain_method=vectorized, <class 'str'>
#     clean_dir=True, <class 'bool'>
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# [I 2022-11-16 23:08:08,571] Trial 0 finished with value: 2.1972245773362196 and parameters: {'n_raters': 48}. Best is trial 0 with value: 2.1972245773362196.
#     p_diff=0.045, <class 'float'>
#     n_raters=52, <class 'int'>
#     scores_per_r=38, <class 'int'>
#     total_scores=None, <class 'NoneType'>
#     n_sims=1, <class 'int'>
#     trials_per_sim=120
#     seed=42, <class 'int'>
#     sim_name=power_2_045, <class 'str'>
#     chain_method=vectorized, <class 'str'>
#     clean_dir=True, <class 'bool'>
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# [I 2022-11-16 23:11:11,919] Trial 1 finished with value: 2.1972245773362196 and parameters: {'n_raters': 52}. Best is trial 0 with value: 2.1972245773362196.
#     p_diff=0.045, <class 'float'>
#     n_raters=175, <class 'int'>
#     scores_per_r=38, <class 'int'>
#     total_scores=None, <class 'NoneType'>
#     n_sims=1, <class 'int'>
#     trials_per_sim=120
#     seed=42, <class 'int'>
#     sim_name=power_2_045, <class 'str'>
#     chain_method=vectorized, <class 'str'>
#     clean_dir=True, <class 'bool'>
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# [I 2022-11-16 23:30:40,725] Trial 2 finished with value: 0.23244594397652363 and parameters: {'n_raters': 175}. Best is trial 2 with value: 0.23244594397652363.
#     p_diff=0.045, <class 'float'>
#     n_raters=91, <class 'int'>
#     scores_per_r=38, <class 'int'>
#     total_scores=None, <class 'NoneType'>
#     n_sims=1, <class 'int'>
#     trials_per_sim=120
#     seed=42, <class 'int'>
#     sim_name=power_2_045, <class 'str'>
#     chain_method=vectorized, <class 'str'>
#     clean_dir=True, <class 'bool'>
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# [I 2022-11-16 23:49:56,642] Trial 3 finished with value: 1.1557707025080588 and parameters: {'n_raters': 91}. Best is trial 2 with value: 0.23244594397652363.
#     p_diff=0.045, <class 'float'>
#     n_raters=140, <class 'int'>
#     scores_per_r=38, <class 'int'>
#     total_scores=None, <class 'NoneType'>
#     n_sims=1, <class 'int'>
#     trials_per_sim=120
#     seed=42, <class 'int'>
#     sim_name=power_2_045, <class 'str'>
#     chain_method=vectorized, <class 'str'>
#     clean_dir=True, <class 'bool'>
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# [I 2022-11-17 00:09:24,038] Trial 4 finished with value: 0.6592456288842636 and parameters: {'n_raters': 140}. Best is trial 2 with value: 0.23244594397652363.
#     p_diff=0.045, <class 'float'>
#     n_raters=151, <class 'int'>
#     scores_per_r=38, <class 'int'>
#     total_scores=None, <class 'NoneType'>
#     n_sims=1, <class 'int'>
#     trials_per_sim=120
#     seed=42, <class 'int'>
#     sim_name=power_2_045, <class 'str'>
#     chain_method=vectorized, <class 'str'>
#     clean_dir=True, <class 'bool'>
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# rm: cannot remove 'data/power_2_045/process_0_running': No such file or directory
# rm: cannot remove 'data/power_2_045/process_1_running': No such file or directory
# rm: cannot remove 'data/power_2_045/process_2_running': No such file or directory
# rm: cannot remove 'data/power_2_045/process_3_running': No such file or directory
# rm: cannot remove 'data/power_2_045/process_5_running': No such file or directory
# [I 2022-11-17 01:02:20,595] Trial 5 finished with value: 0.5069345682730237 and parameters: {'n_raters': 151}. Best is trial 2 with value: 0.23244594397652363.
#     p_diff=0.045, <class 'float'>
#     n_raters=144, <class 'int'>
#     scores_per_r=38, <class 'int'>
#     total_scores=None, <class 'NoneType'>
#     n_sims=1, <class 'int'>
#     trials_per_sim=120
#     seed=42, <class 'int'>
#     sim_name=power_2_045, <class 'str'>
#     chain_method=vectorized, <class 'str'>
#     clean_dir=True, <class 'bool'>
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# [I 2022-11-17 01:19:41,753] Trial 6 finished with value: 0.7091475219063867 and parameters: {'n_raters': 144}. Best is trial 2 with value: 0.23244594397652363.
#     p_diff=0.045, <class 'float'>
#     n_raters=153, <class 'int'>
#     scores_per_r=38, <class 'int'>
#     total_scores=None, <class 'NoneType'>
#     n_sims=1, <class 'int'>
#     trials_per_sim=120
#     seed=42, <class 'int'>
#     sim_name=power_2_045, <class 'str'>
#     chain_method=vectorized, <class 'str'>
#     clean_dir=True, <class 'bool'>
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# [I 2022-11-17 01:46:21,948] Trial 7 finished with value: 0.21868920096482958 and parameters: {'n_raters': 153}. Best is trial 7 with value: 0.21868920096482958.
#     p_diff=0.045, <class 'float'>
#     n_raters=116, <class 'int'>
#     scores_per_r=38, <class 'int'>
#     total_scores=None, <class 'NoneType'>
#     n_sims=1, <class 'int'>
#     trials_per_sim=120
#     seed=42, <class 'int'>
#     sim_name=power_2_045, <class 'str'>
#     chain_method=vectorized, <class 'str'>
#     clean_dir=True, <class 'bool'>
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# [I 2022-11-17 02:11:30,679] Trial 8 finished with value: 0.44320543609101204 and parameters: {'n_raters': 116}. Best is trial 7 with value: 0.21868920096482958.
#     p_diff=0.045, <class 'float'>
#     n_raters=129, <class 'int'>
#     scores_per_r=38, <class 'int'>
#     total_scores=None, <class 'NoneType'>
#     n_sims=1, <class 'int'>
#     trials_per_sim=120
#     seed=42, <class 'int'>
#     sim_name=power_2_045, <class 'str'>
#     chain_method=vectorized, <class 'str'>
#     clean_dir=True, <class 'bool'>
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# [I 2022-11-17 02:38:00,613] Trial 9 finished with value: 0.306374205463934 and parameters: {'n_raters': 129}. Best is trial 7 with value: 0.21868920096482958.
#     p_diff=0.045, <class 'float'>
#     n_raters=198, <class 'int'>
#     scores_per_r=38, <class 'int'>
#     total_scores=None, <class 'NoneType'>
#     n_sims=1, <class 'int'>
#     trials_per_sim=120
#     seed=42, <class 'int'>
#     sim_name=power_2_045, <class 'str'>
#     chain_method=vectorized, <class 'str'>
#     clean_dir=True, <class 'bool'>
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# [I 2022-11-17 03:03:09,775] Trial 10 finished with value: 0.07082605256861285 and parameters: {'n_raters': 198}. Best is trial 10 with value: 0.07082605256861285.
#     p_diff=0.045, <class 'float'>
#     n_raters=198, <class 'int'>
#     scores_per_r=38, <class 'int'>
#     total_scores=None, <class 'NoneType'>
#     n_sims=1, <class 'int'>
#     trials_per_sim=120
#     seed=42, <class 'int'>
#     sim_name=power_2_045, <class 'str'>
#     chain_method=vectorized, <class 'str'>
#     clean_dir=True, <class 'bool'>
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# [I 2022-11-17 03:26:08,922] Trial 11 finished with value: 0.07082605256861285 and parameters: {'n_raters': 198}. Best is trial 10 with value: 0.07082605256861285.
#     p_diff=0.045, <class 'float'>
#     n_raters=199, <class 'int'>
#     scores_per_r=38, <class 'int'>
#     total_scores=None, <class 'NoneType'>
#     n_sims=1, <class 'int'>
#     trials_per_sim=120
#     seed=42, <class 'int'>
# ...
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# [I 2022-11-17 23:11:43,355] Trial 65 finished with value: 0.07082605256861285 and parameters: {'n_raters': 137}. Best is trial 21 with value: 0.018349138668196208.
#     p_diff=0.045, <class 'float'>
#     n_raters=101, <class 'int'>
#     scores_per_r=38, <class 'int'>
#     total_scores=None, <class 'NoneType'>
#     n_sims=1, <class 'int'>
#     trials_per_sim=120
#     seed=42, <class 'int'>
#     sim_name=power_2_045, <class 'str'>
#     chain_method=vectorized, <class 'str'>
#     clean_dir=True, <class 'bool'>
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# [I 2022-11-17 23:15:47,111] Trial 66 finished with value: 1.2809338454620645 and parameters: {'n_raters': 101}. Best is trial 21 with value: 0.018349138668196208.
#     p_diff=0.045, <class 'float'>
#     n_raters=167, <class 'int'>
#     scores_per_r=38, <class 'int'>
#     total_scores=None, <class 'NoneType'>
#     n_sims=1, <class 'int'>
#     trials_per_sim=120
#     seed=42, <class 'int'>
#     sim_name=power_2_045, <class 'str'>
#     chain_method=vectorized, <class 'str'>
#     clean_dir=True, <class 'bool'>
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# [I 2022-11-17 23:48:00,897] Trial 67 finished with value: 0.7646061445420891 and parameters: {'n_raters': 167}. Best is trial 21 with value: 0.018349138668196208.
#     p_diff=0.045, <class 'float'>
#     n_raters=95, <class 'int'>
#     scores_per_r=38, <class 'int'>
#     total_scores=None, <class 'NoneType'>
#     n_sims=1, <class 'int'>
#     trials_per_sim=120
#     seed=42, <class 'int'>
#     sim_name=power_2_045, <class 'str'>
#     chain_method=vectorized, <class 'str'>
#     clean_dir=True, <class 'bool'>
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# [I 2022-11-18 00:10:48,190] Trial 68 finished with value: 0.6390799592896697 and parameters: {'n_raters': 95}. Best is trial 21 with value: 0.018349138668196208.
#     p_diff=0.045, <class 'float'>
#     n_raters=109, <class 'int'>
#     scores_per_r=38, <class 'int'>
#     total_scores=None, <class 'NoneType'>
#     n_sims=1, <class 'int'>
#     trials_per_sim=120
#     seed=42, <class 'int'>
#     sim_name=power_2_045, <class 'str'>
#     chain_method=vectorized, <class 'str'>
#     clean_dir=True, <class 'bool'>
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# [I 2022-11-18 00:29:10,121] Trial 69 finished with value: 0.7548407495652854 and parameters: {'n_raters': 109}. Best is trial 21 with value: 0.018349138668196208.

# %%
sim_name = "power_2_055"
OA = False

power_id, p_diff = 0, 0.055
# for power_id, p_diff in enumerate(np.geomspace(0.02, 0.2, num=10)):
# list is used so that sim_id can be incremented in objective func  
sim_id = [0]
study = optuna.create_study(direction="minimize")
study.optimize(objective, n_trials=n_sims)
df = pd.DataFrame([[power_id, p_diff, study.best_trial.number,
                  study.best_params["n_raters"]]],
                  columns=["power_id", "p_diff", "best_trial", "n_raters"]) # Join power when all is complete
if power_id == 0:
    df.to_csv(f"data/simulations/optuna_log_{sim_name}.csv", index=False)
else:
    log=pd.read_csv(f"data/simulations/optuna_log_{sim_name}.csv")
    pd.concat([log, df]).to_csv(f"data/simulations/optuna_log_{sim_name}.csv", index=False)
# Out:
# [I 2022-11-18 00:29:10,139] A new study created in memory with name: no-name-eb3fae1c-2d17-4ba4-a7f2-6b8fbd748229
#     p_diff=0.055, <class 'float'>
#     n_raters=125, <class 'int'>
#     scores_per_r=38, <class 'int'>
#     total_scores=None, <class 'NoneType'>
#     n_sims=1, <class 'int'>
#     trials_per_sim=120
#     seed=42, <class 'int'>
#     sim_name=power_2_055, <class 'str'>
#     chain_method=vectorized, <class 'str'>
#     clean_dir=True, <class 'bool'>
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# [I 2022-11-18 01:01:08,515] Trial 0 finished with value: 0.4595323293784408 and parameters: {'n_raters': 125}. Best is trial 0 with value: 0.4595323293784408.
#     p_diff=0.055, <class 'float'>
#     n_raters=65, <class 'int'>
#     scores_per_r=38, <class 'int'>
#     total_scores=None, <class 'NoneType'>
#     n_sims=1, <class 'int'>
#     trials_per_sim=120
#     seed=42, <class 'int'>
#     sim_name=power_2_055, <class 'str'>
#     chain_method=vectorized, <class 'str'>
#     clean_dir=True, <class 'bool'>
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# [I 2022-11-18 01:23:24,859] Trial 1 finished with value: 0.7129498078561256 and parameters: {'n_raters': 65}. Best is trial 0 with value: 0.4595323293784408.
#     p_diff=0.055, <class 'float'>
#     n_raters=157, <class 'int'>
#     scores_per_r=38, <class 'int'>
#     total_scores=None, <class 'NoneType'>
#     n_sims=1, <class 'int'>
#     trials_per_sim=120
#     seed=42, <class 'int'>
#     sim_name=power_2_055, <class 'str'>
#     chain_method=vectorized, <class 'str'>
#     clean_dir=True, <class 'bool'>
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# [I 2022-11-18 01:35:08,422] Trial 2 finished with value: 1.5639755383573437 and parameters: {'n_raters': 157}. Best is trial 0 with value: 0.4595323293784408.
#     p_diff=0.055, <class 'float'>
#     n_raters=164, <class 'int'>
#     scores_per_r=38, <class 'int'>
#     total_scores=None, <class 'NoneType'>
#     n_sims=1, <class 'int'>
#     trials_per_sim=120
#     seed=42, <class 'int'>
#     sim_name=power_2_055, <class 'str'>
#     chain_method=vectorized, <class 'str'>
#     clean_dir=True, <class 'bool'>
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# [I 2022-11-18 02:00:52,781] Trial 3 finished with value: 0.21868920096482958 and parameters: {'n_raters': 164}. Best is trial 3 with value: 0.21868920096482958.
#     p_diff=0.055, <class 'float'>
#     n_raters=130, <class 'int'>
#     scores_per_r=38, <class 'int'>
#     total_scores=None, <class 'NoneType'>
#     n_sims=1, <class 'int'>
#     trials_per_sim=120
#     seed=42, <class 'int'>
#     sim_name=power_2_055, <class 'str'>
#     chain_method=vectorized, <class 'str'>
#     clean_dir=True, <class 'bool'>
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# [I 2022-11-18 02:27:35,960] Trial 4 finished with value: 0.07082605256861285 and parameters: {'n_raters': 130}. Best is trial 4 with value: 0.07082605256861285.
#     p_diff=0.055, <class 'float'>
#     n_raters=167, <class 'int'>
#     scores_per_r=38, <class 'int'>
#     total_scores=None, <class 'NoneType'>
#     n_sims=1, <class 'int'>
#     trials_per_sim=120
#     seed=42, <class 'int'>
#     sim_name=power_2_055, <class 'str'>
#     chain_method=vectorized, <class 'str'>
#     clean_dir=True, <class 'bool'>
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# [I 2022-11-18 02:51:00,082] Trial 5 finished with value: 0.6592456288842636 and parameters: {'n_raters': 167}. Best is trial 4 with value: 0.07082605256861285.
#     p_diff=0.055, <class 'float'>
#     n_raters=47, <class 'int'>
#     scores_per_r=38, <class 'int'>
#     total_scores=None, <class 'NoneType'>
#     n_sims=1, <class 'int'>
#     trials_per_sim=120
#     seed=42, <class 'int'>
#     sim_name=power_2_055, <class 'str'>
#     chain_method=vectorized, <class 'str'>
#     clean_dir=True, <class 'bool'>
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# [I 2022-11-18 03:13:58,017] Trial 6 finished with value: 1.0397717886451763 and parameters: {'n_raters': 47}. Best is trial 4 with value: 0.07082605256861285.
#     p_diff=0.055, <class 'float'>
#     n_raters=175, <class 'int'>
#     scores_per_r=38, <class 'int'>
#     total_scores=None, <class 'NoneType'>
#     n_sims=1, <class 'int'>
#     trials_per_sim=120
#     seed=42, <class 'int'>
#     sim_name=power_2_055, <class 'str'>
#     chain_method=vectorized, <class 'str'>
#     clean_dir=True, <class 'bool'>
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# [I 2022-11-18 03:35:21,873] Trial 7 finished with value: 0.893817876022097 and parameters: {'n_raters': 175}. Best is trial 4 with value: 0.07082605256861285.
#     p_diff=0.055, <class 'float'>
#     n_raters=181, <class 'int'>
#     scores_per_r=38, <class 'int'>
#     total_scores=None, <class 'NoneType'>
#     n_sims=1, <class 'int'>
#     trials_per_sim=120
#     seed=42, <class 'int'>
#     sim_name=power_2_055, <class 'str'>
#     chain_method=vectorized, <class 'str'>
#     clean_dir=True, <class 'bool'>
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# [I 2022-11-18 03:46:38,461] Trial 8 finished with value: 1.5639755383573437 and parameters: {'n_raters': 181}. Best is trial 4 with value: 0.07082605256861285.
#     p_diff=0.055, <class 'float'>
#     n_raters=89, <class 'int'>
#     scores_per_r=38, <class 'int'>
#     total_scores=None, <class 'NoneType'>
#     n_sims=1, <class 'int'>
#     trials_per_sim=120
#     seed=42, <class 'int'>
#     sim_name=power_2_055, <class 'str'>
#     chain_method=vectorized, <class 'str'>
#     clean_dir=True, <class 'bool'>
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# [I 2022-11-18 04:10:27,284] Trial 9 finished with value: 0.4595323293784408 and parameters: {'n_raters': 89}. Best is trial 4 with value: 0.07082605256861285.
#     p_diff=0.055, <class 'float'>
#     n_raters=123, <class 'int'>
#     scores_per_r=38, <class 'int'>
#     total_scores=None, <class 'NoneType'>
#     n_sims=1, <class 'int'>
#     trials_per_sim=120
#     seed=42, <class 'int'>
#     sim_name=power_2_055, <class 'str'>
#     chain_method=vectorized, <class 'str'>
#     clean_dir=True, <class 'bool'>
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# [I 2022-11-18 04:41:16,589] Trial 10 finished with value: 0.21868920096482958 and parameters: {'n_raters': 123}. Best is trial 4 with value: 0.07082605256861285.
#     p_diff=0.055, <class 'float'>
#     n_raters=138, <class 'int'>
#     scores_per_r=38, <class 'int'>
#     total_scores=None, <class 'NoneType'>
#     n_sims=1, <class 'int'>
#     trials_per_sim=120
#     seed=42, <class 'int'>
#     sim_name=power_2_055, <class 'str'>
#     chain_method=vectorized, <class 'str'>
#     clean_dir=True, <class 'bool'>
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# ...
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# [I 2022-11-19 01:33:33,471] Trial 64 finished with value: 0.11441035117774412 and parameters: {'n_raters': 100}. Best is trial 15 with value: 0.018349138668196208.
#     p_diff=0.055, <class 'float'>
#     n_raters=131, <class 'int'>
#     scores_per_r=38, <class 'int'>
#     total_scores=None, <class 'NoneType'>
#     n_sims=1, <class 'int'>
#     trials_per_sim=120
#     seed=42, <class 'int'>
#     sim_name=power_2_055, <class 'str'>
#     chain_method=vectorized, <class 'str'>
#     clean_dir=True, <class 'bool'>
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# [I 2022-11-19 01:46:38,128] Trial 65 finished with value: 1.5639755383573437 and parameters: {'n_raters': 131}. Best is trial 15 with value: 0.018349138668196208.
#     p_diff=0.055, <class 'float'>
#     n_raters=146, <class 'int'>
#     scores_per_r=38, <class 'int'>
#     total_scores=None, <class 'NoneType'>
#     n_sims=1, <class 'int'>
#     trials_per_sim=120
#     seed=42, <class 'int'>
#     sim_name=power_2_055, <class 'str'>
#     chain_method=vectorized, <class 'str'>
#     clean_dir=True, <class 'bool'>
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# [I 2022-11-19 02:21:38,691] Trial 66 finished with value: 0.601797401971718 and parameters: {'n_raters': 146}. Best is trial 15 with value: 0.018349138668196208.
#     p_diff=0.055, <class 'float'>
#     n_raters=89, <class 'int'>
#     scores_per_r=38, <class 'int'>
#     total_scores=None, <class 'NoneType'>
#     n_sims=1, <class 'int'>
#     trials_per_sim=120
#     seed=42, <class 'int'>
#     sim_name=power_2_055, <class 'str'>
#     chain_method=vectorized, <class 'str'>
#     clean_dir=True, <class 'bool'>
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# [I 2022-11-19 02:38:30,924] Trial 67 finished with value: 0.4595323293784408 and parameters: {'n_raters': 89}. Best is trial 15 with value: 0.018349138668196208.
#     p_diff=0.055, <class 'float'>
#     n_raters=49, <class 'int'>
#     scores_per_r=38, <class 'int'>
#     total_scores=None, <class 'NoneType'>
#     n_sims=1, <class 'int'>
#     trials_per_sim=120
#     seed=42, <class 'int'>
#     sim_name=power_2_055, <class 'str'>
#     chain_method=vectorized, <class 'str'>
#     clean_dir=True, <class 'bool'>
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# [I 2022-11-19 02:42:28,414] Trial 68 finished with value: 1.2809338454620645 and parameters: {'n_raters': 49}. Best is trial 15 with value: 0.018349138668196208.
#     p_diff=0.055, <class 'float'>
#     n_raters=72, <class 'int'>
#     scores_per_r=38, <class 'int'>
#     total_scores=None, <class 'NoneType'>
#     n_sims=1, <class 'int'>
#     trials_per_sim=120
#     seed=42, <class 'int'>
#     sim_name=power_2_055, <class 'str'>
#     chain_method=vectorized, <class 'str'>
#     clean_dir=True, <class 'bool'>
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# [I 2022-11-19 02:46:01,936] Trial 69 finished with value: 1.2809338454620645 and parameters: {'n_raters': 72}. Best is trial 15 with value: 0.018349138668196208.

# %%
sim_name = "power_2_070"
OA = False

power_id, p_diff = 0, 0.070
# for power_id, p_diff in enumerate(np.geomspace(0.02, 0.2, num=10)):
# list is used so that sim_id can be incremented in objective func  
sim_id = [0]
study = optuna.create_study(direction="minimize")
study.optimize(objective, n_trials=n_sims)
df = pd.DataFrame([[power_id, p_diff, study.best_trial.number,
                  study.best_params["n_raters"]]],
                  columns=["power_id", "p_diff", "best_trial", "n_raters"]) # Join power when all is complete
if power_id == 0:
    df.to_csv(f"data/simulations/optuna_log_{sim_name}.csv", index=False)
else:
    log=pd.read_csv(f"data/simulations/optuna_log_{sim_name}.csv")
    pd.concat([log, df]).to_csv(f"data/simulations/optuna_log_{sim_name}.csv", index=False)

# %%
sim_name = "power_2_OA045"
OA = True

power_id, p_diff = 0, 0.045
# for power_id, p_diff in enumerate(np.geomspace(0.02, 0.2, num=10)):
# list is used so that sim_id can be incremented in objective func  
sim_id = [0]
study = optuna.create_study(direction="minimize")
study.optimize(objective, n_trials=n_sims)
df = pd.DataFrame([[power_id, p_diff, study.best_trial.number,
                  study.best_params["n_raters"]]],
                  columns=["power_id", "p_diff", "best_trial", "n_raters"]) # Join power when all is complete
if power_id == 0:
    df.to_csv(f"data/simulations/optuna_log_{sim_name}.csv", index=False)
else:
    log=pd.read_csv(f"data/simulations/optuna_log_{sim_name}.csv")
    pd.concat([log, df]).to_csv(f"data/simulations/optuna_log_{sim_name}.csv", index=False)
# Out:
# [I 2022-11-20 10:08:20,259] A new study created in memory with name: no-name-da44146d-c48e-4ec9-bb9e-8dfa9112b103
#     p_diff=0.045, <class 'float'>
#     n_raters=30, <class 'int'>
#     scores_per_r=38, <class 'int'>
#     total_scores=None, <class 'NoneType'>
#     n_sims=1, <class 'int'>
#     trials_per_sim=120
#     seed=42, <class 'int'>
#     sim_name=power_2_OA045, <class 'str'>
#     chain_method=vectorized, <class 'str'>
#     clean_dir=True, <class 'bool'>
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# [I 2022-11-20 10:12:35,420] Trial 0 finished with value: 2.1972245773362196 and parameters: {'n_raters': 30}. Best is trial 0 with value: 2.1972245773362196.
#     p_diff=0.045, <class 'float'>
#     n_raters=108, <class 'int'>
#     scores_per_r=38, <class 'int'>
#     total_scores=None, <class 'NoneType'>
#     n_sims=1, <class 'int'>
#     trials_per_sim=120
#     seed=42, <class 'int'>
#     sim_name=power_2_OA045, <class 'str'>
#     chain_method=vectorized, <class 'str'>
#     clean_dir=True, <class 'bool'>
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# [I 2022-11-20 10:49:10,562] Trial 1 finished with value: 0.1541506798272585 and parameters: {'n_raters': 108}. Best is trial 1 with value: 0.1541506798272585.
#     p_diff=0.045, <class 'float'>
#     n_raters=30, <class 'int'>
#     scores_per_r=38, <class 'int'>
#     total_scores=None, <class 'NoneType'>
#     n_sims=1, <class 'int'>
#     trials_per_sim=120
#     seed=42, <class 'int'>
#     sim_name=power_2_OA045, <class 'str'>
#     chain_method=vectorized, <class 'str'>
#     clean_dir=True, <class 'bool'>
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# [I 2022-11-20 10:52:42,797] Trial 2 finished with value: 2.1972245773362196 and parameters: {'n_raters': 30}. Best is trial 1 with value: 0.1541506798272585.
#     p_diff=0.045, <class 'float'>
#     n_raters=33, <class 'int'>
#     scores_per_r=38, <class 'int'>
#     total_scores=None, <class 'NoneType'>
#     n_sims=1, <class 'int'>
#     trials_per_sim=120
#     seed=42, <class 'int'>
#     sim_name=power_2_OA045, <class 'str'>
#     chain_method=vectorized, <class 'str'>
#     clean_dir=True, <class 'bool'>
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# [I 2022-11-20 10:57:05,104] Trial 3 finished with value: 2.7850112422383386 and parameters: {'n_raters': 33}. Best is trial 1 with value: 0.1541506798272585.
#     p_diff=0.045, <class 'float'>
#     n_raters=73, <class 'int'>
#     scores_per_r=38, <class 'int'>
#     total_scores=None, <class 'NoneType'>
#     n_sims=1, <class 'int'>
#     trials_per_sim=120
#     seed=42, <class 'int'>
#     sim_name=power_2_OA045, <class 'str'>
#     chain_method=vectorized, <class 'str'>
#     clean_dir=True, <class 'bool'>
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# [I 2022-11-20 11:10:37,970] Trial 4 finished with value: 0.9734491457141041 and parameters: {'n_raters': 73}. Best is trial 1 with value: 0.1541506798272585.
#     p_diff=0.045, <class 'float'>
#     n_raters=67, <class 'int'>
#     scores_per_r=38, <class 'int'>
#     total_scores=None, <class 'NoneType'>
#     n_sims=1, <class 'int'>
#     trials_per_sim=120
#     seed=42, <class 'int'>
#     sim_name=power_2_OA045, <class 'str'>
#     chain_method=vectorized, <class 'str'>
#     clean_dir=True, <class 'bool'>
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# [I 2022-11-20 11:15:02,390] Trial 5 finished with value: 1.6094379124341005 and parameters: {'n_raters': 67}. Best is trial 1 with value: 0.1541506798272585.
#     p_diff=0.045, <class 'float'>
#     n_raters=96, <class 'int'>
#     scores_per_r=38, <class 'int'>
#     total_scores=None, <class 'NoneType'>
#     n_sims=1, <class 'int'>
#     trials_per_sim=120
#     seed=42, <class 'int'>
#     sim_name=power_2_OA045, <class 'str'>
#     chain_method=vectorized, <class 'str'>
#     clean_dir=True, <class 'bool'>
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# [I 2022-11-20 11:48:50,163] Trial 6 finished with value: 0.7308875085427926 and parameters: {'n_raters': 96}. Best is trial 1 with value: 0.1541506798272585.
#     p_diff=0.045, <class 'float'>
#     n_raters=63, <class 'int'>
#     scores_per_r=38, <class 'int'>
#     total_scores=None, <class 'NoneType'>
#     n_sims=1, <class 'int'>
#     trials_per_sim=120
#     seed=42, <class 'int'>
#     sim_name=power_2_OA045, <class 'str'>
#     chain_method=vectorized, <class 'str'>
#     clean_dir=True, <class 'bool'>
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# [I 2022-11-20 11:53:17,423] Trial 7 finished with value: 1.2809338454620645 and parameters: {'n_raters': 63}. Best is trial 1 with value: 0.1541506798272585.
#     p_diff=0.045, <class 'float'>
#     n_raters=124, <class 'int'>
#     scores_per_r=38, <class 'int'>
#     total_scores=None, <class 'NoneType'>
#     n_sims=1, <class 'int'>
#     trials_per_sim=120
#     seed=42, <class 'int'>
#     sim_name=power_2_OA045, <class 'str'>
#     chain_method=vectorized, <class 'str'>
#     clean_dir=True, <class 'bool'>
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# [I 2022-11-20 12:30:27,418] Trial 8 finished with value: 0.11441035117774412 and parameters: {'n_raters': 124}. Best is trial 8 with value: 0.11441035117774412.
#     p_diff=0.045, <class 'float'>
#     n_raters=86, <class 'int'>
#     scores_per_r=38, <class 'int'>
#     total_scores=None, <class 'NoneType'>
#     n_sims=1, <class 'int'>
#     trials_per_sim=120
#     seed=42, <class 'int'>
#     sim_name=power_2_OA045, <class 'str'>
#     chain_method=vectorized, <class 'str'>
#     clean_dir=True, <class 'bool'>
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# [I 2022-11-20 13:07:00,802] Trial 9 finished with value: 0.44320543609101204 and parameters: {'n_raters': 86}. Best is trial 8 with value: 0.11441035117774412.
#     p_diff=0.045, <class 'float'>
#     n_raters=164, <class 'int'>
#     scores_per_r=38, <class 'int'>
#     total_scores=None, <class 'NoneType'>
#     n_sims=1, <class 'int'>
#     trials_per_sim=120
#     seed=42, <class 'int'>
#     sim_name=power_2_OA045, <class 'str'>
#     chain_method=vectorized, <class 'str'>
#     clean_dir=True, <class 'bool'>
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# [I 2022-11-20 13:40:51,936] Trial 10 finished with value: 0.5154660033224931 and parameters: {'n_raters': 164}. Best is trial 8 with value: 0.11441035117774412.
#     p_diff=0.045, <class 'float'>
#     n_raters=142, <class 'int'>
#     scores_per_r=38, <class 'int'>
#     total_scores=None, <class 'NoneType'>
#     n_sims=1, <class 'int'>
#     trials_per_sim=120
#     seed=42, <class 'int'>
#     sim_name=power_2_OA045, <class 'str'>
#     chain_method=vectorized, <class 'str'>
#     clean_dir=True, <class 'bool'>
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# [I 2022-11-20 14:19:22,236] Trial 11 finished with value: 0.21868920096482958 and parameters: {'n_raters': 142}. Best is trial 8 with value: 0.11441035117774412.
#     p_diff=0.045, <class 'float'>
#     n_raters=125, <class 'int'>
#     scores_per_r=38, <class 'int'>
#     total_scores=None, <class 'NoneType'>
#     n_sims=1, <class 'int'>
#     trials_per_sim=120
#     seed=42, <class 'int'>
#     sim_name=power_2_OA045, <class 'str'>
#     chain_method=vectorized, <class 'str'>
#     clean_dir=True, <class 'bool'>
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# [I 2022-11-20 14:56:41,221] Trial 12 finished with value: 0.23244594397652363 and parameters: {'n_raters': 125}. Best is trial 8 with value: 0.11441035117774412.
#     p_diff=0.045, <class 'float'>
#     n_raters=188, <class 'int'>
#     scores_per_r=38, <class 'int'>
#     total_scores=None, <class 'NoneType'>
#     n_sims=1, <class 'int'>
#     trials_per_sim=120
#     seed=42, <class 'int'>
#     sim_name=power_2_OA045, <class 'str'>
#     chain_method=vectorized, <class 'str'>
#     clean_dir=True, <class 'bool'>
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# ...
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# [I 2022-11-21 20:03:26,766] Trial 65 finished with value: 0.4595323293784408 and parameters: {'n_raters': 184}. Best is trial 31 with value: 0.018349138668196208.
#     p_diff=0.045, <class 'float'>
#     n_raters=145, <class 'int'>
#     scores_per_r=38, <class 'int'>
#     total_scores=None, <class 'NoneType'>
#     n_sims=1, <class 'int'>
#     trials_per_sim=120
#     seed=42, <class 'int'>
#     sim_name=power_2_OA045, <class 'str'>
#     chain_method=vectorized, <class 'str'>
#     clean_dir=True, <class 'bool'>
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# [I 2022-11-21 20:08:36,291] Trial 66 finished with value: 1.2809338454620645 and parameters: {'n_raters': 145}. Best is trial 31 with value: 0.018349138668196208.
#     p_diff=0.045, <class 'float'>
#     n_raters=122, <class 'int'>
#     scores_per_r=38, <class 'int'>
#     total_scores=None, <class 'NoneType'>
#     n_sims=1, <class 'int'>
#     trials_per_sim=120
#     seed=42, <class 'int'>
#     sim_name=power_2_OA045, <class 'str'>
#     chain_method=vectorized, <class 'str'>
#     clean_dir=True, <class 'bool'>
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# [I 2022-11-21 20:24:10,981] Trial 67 finished with value: 0.8391010931830256 and parameters: {'n_raters': 122}. Best is trial 31 with value: 0.018349138668196208.
#     p_diff=0.045, <class 'float'>
#     n_raters=200, <class 'int'>
#     scores_per_r=38, <class 'int'>
#     total_scores=None, <class 'NoneType'>
#     n_sims=1, <class 'int'>
#     trials_per_sim=120
#     seed=42, <class 'int'>
#     sim_name=power_2_OA045, <class 'str'>
#     chain_method=vectorized, <class 'str'>
#     clean_dir=True, <class 'bool'>
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# [I 2022-11-21 21:08:51,263] Trial 68 finished with value: 0.33293866403990213 and parameters: {'n_raters': 200}. Best is trial 31 with value: 0.018349138668196208.
#     p_diff=0.045, <class 'float'>
#     n_raters=139, <class 'int'>
#     scores_per_r=38, <class 'int'>
#     total_scores=None, <class 'NoneType'>
#     n_sims=1, <class 'int'>
#     trials_per_sim=120
#     seed=42, <class 'int'>
#     sim_name=power_2_OA045, <class 'str'>
#     chain_method=vectorized, <class 'str'>
#     clean_dir=True, <class 'bool'>
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# rm: cannot remove 'data/power_2_OA045/process_3_running': No such file or directory
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# [I 2022-11-21 21:59:52,699] Trial 69 finished with value: 0.7399784802440446 and parameters: {'n_raters': 139}. Best is trial 31 with value: 0.018349138668196208.

# %%
sim_name = "power_2_OA055"
OA = True

power_id, p_diff = 0, 0.055
# for power_id, p_diff in enumerate(np.geomspace(0.02, 0.2, num=10)):
# list is used so that sim_id can be incremented in objective func  
sim_id = [0]
study = optuna.create_study(direction="minimize")
study.optimize(objective, n_trials=n_sims)
df = pd.DataFrame([[power_id, p_diff, study.best_trial.number,
                  study.best_params["n_raters"]]],
                  columns=["power_id", "p_diff", "best_trial", "n_raters"]) # Join power when all is complete
if power_id == 0:
    df.to_csv(f"data/simulations/optuna_log_{sim_name}.csv", index=False)
else:
    log=pd.read_csv(f"data/simulations/optuna_log_{sim_name}.csv")
    pd.concat([log, df]).to_csv(f"data/simulations/optuna_log_{sim_name}.csv", index=False)
# Out:
# [I 2022-11-21 21:59:52,825] A new study created in memory with name: no-name-e35d8497-fe4f-41a1-83b3-e11b8993db73
#     p_diff=0.055, <class 'float'>
#     n_raters=57, <class 'int'>
#     scores_per_r=38, <class 'int'>
#     total_scores=None, <class 'NoneType'>
#     n_sims=1, <class 'int'>
#     trials_per_sim=120
#     seed=42, <class 'int'>
#     sim_name=power_2_OA055, <class 'str'>
#     chain_method=vectorized, <class 'str'>
#     clean_dir=True, <class 'bool'>
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# [I 2022-11-21 22:15:06,654] Trial 0 finished with value: 1.0986122886681098 and parameters: {'n_raters': 57}. Best is trial 0 with value: 1.0986122886681098.
#     p_diff=0.055, <class 'float'>
#     n_raters=166, <class 'int'>
#     scores_per_r=38, <class 'int'>
#     total_scores=None, <class 'NoneType'>
#     n_sims=1, <class 'int'>
#     trials_per_sim=120
#     seed=42, <class 'int'>
#     sim_name=power_2_OA055, <class 'str'>
#     chain_method=vectorized, <class 'str'>
#     clean_dir=True, <class 'bool'>
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# [I 2022-11-21 22:58:26,683] Trial 1 finished with value: 0.018349138668196208 and parameters: {'n_raters': 166}. Best is trial 1 with value: 0.018349138668196208.
#     p_diff=0.055, <class 'float'>
#     n_raters=129, <class 'int'>
#     scores_per_r=38, <class 'int'>
#     total_scores=None, <class 'NoneType'>
#     n_sims=1, <class 'int'>
#     trials_per_sim=120
#     seed=42, <class 'int'>
#     sim_name=power_2_OA055, <class 'str'>
#     chain_method=vectorized, <class 'str'>
#     clean_dir=True, <class 'bool'>
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# [I 2022-11-21 23:14:06,687] Trial 2 finished with value: 1.5639755383573437 and parameters: {'n_raters': 129}. Best is trial 1 with value: 0.018349138668196208.
#     p_diff=0.055, <class 'float'>
#     n_raters=148, <class 'int'>
#     scores_per_r=38, <class 'int'>
#     total_scores=None, <class 'NoneType'>
#     n_sims=1, <class 'int'>
#     trials_per_sim=120
#     seed=42, <class 'int'>
#     sim_name=power_2_OA055, <class 'str'>
#     chain_method=vectorized, <class 'str'>
#     clean_dir=True, <class 'bool'>
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# [I 2022-11-22 00:17:36,160] Trial 3 finished with value: 0.4595323293784408 and parameters: {'n_raters': 148}. Best is trial 1 with value: 0.018349138668196208.
#     p_diff=0.055, <class 'float'>
#     n_raters=164, <class 'int'>
#     scores_per_r=38, <class 'int'>
#     total_scores=None, <class 'NoneType'>
#     n_sims=1, <class 'int'>
#     trials_per_sim=120
#     seed=42, <class 'int'>
#     sim_name=power_2_OA055, <class 'str'>
#     chain_method=vectorized, <class 'str'>
#     clean_dir=True, <class 'bool'>
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# [I 2022-11-22 01:01:16,568] Trial 4 finished with value: 0.11441035117774412 and parameters: {'n_raters': 164}. Best is trial 1 with value: 0.018349138668196208.
#     p_diff=0.055, <class 'float'>
#     n_raters=56, <class 'int'>
#     scores_per_r=38, <class 'int'>
#     total_scores=None, <class 'NoneType'>
#     n_sims=1, <class 'int'>
#     trials_per_sim=120
#     seed=42, <class 'int'>
#     sim_name=power_2_OA055, <class 'str'>
#     chain_method=vectorized, <class 'str'>
#     clean_dir=True, <class 'bool'>
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# [I 2022-11-22 01:08:52,236] Trial 5 finished with value: 1.0185695809945736 and parameters: {'n_raters': 56}. Best is trial 1 with value: 0.018349138668196208.
#     p_diff=0.055, <class 'float'>
#     n_raters=195, <class 'int'>
#     scores_per_r=38, <class 'int'>
#     total_scores=None, <class 'NoneType'>
#     n_sims=1, <class 'int'>
#     trials_per_sim=120
#     seed=42, <class 'int'>
#     sim_name=power_2_OA055, <class 'str'>
#     chain_method=vectorized, <class 'str'>
#     clean_dir=True, <class 'bool'>
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# [I 2022-11-22 01:53:38,913] Trial 6 finished with value: 0.7646061445420891 and parameters: {'n_raters': 195}. Best is trial 1 with value: 0.018349138668196208.
#     p_diff=0.055, <class 'float'>
#     n_raters=105, <class 'int'>
#     scores_per_r=38, <class 'int'>
#     total_scores=None, <class 'NoneType'>
#     n_sims=1, <class 'int'>
#     trials_per_sim=120
#     seed=42, <class 'int'>
#     sim_name=power_2_OA055, <class 'str'>
#     chain_method=vectorized, <class 'str'>
#     clean_dir=True, <class 'bool'>
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# [I 2022-11-22 02:36:29,651] Trial 7 finished with value: 0.33293866403990213 and parameters: {'n_raters': 105}. Best is trial 1 with value: 0.018349138668196208.
#     p_diff=0.055, <class 'float'>
#     n_raters=180, <class 'int'>
#     scores_per_r=38, <class 'int'>
#     total_scores=None, <class 'NoneType'>
#     n_sims=1, <class 'int'>
#     trials_per_sim=120
#     seed=42, <class 'int'>
#     sim_name=power_2_OA055, <class 'str'>
#     chain_method=vectorized, <class 'str'>
#     clean_dir=True, <class 'bool'>
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# [I 2022-11-22 03:16:00,604] Trial 8 finished with value: 0.4595323293784408 and parameters: {'n_raters': 180}. Best is trial 1 with value: 0.018349138668196208.
#     p_diff=0.055, <class 'float'>
#     n_raters=105, <class 'int'>
#     scores_per_r=38, <class 'int'>
#     total_scores=None, <class 'NoneType'>
#     n_sims=1, <class 'int'>
#     trials_per_sim=120
#     seed=42, <class 'int'>
#     sim_name=power_2_OA055, <class 'str'>
#     chain_method=vectorized, <class 'str'>
#     clean_dir=True, <class 'bool'>
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# [I 2022-11-22 03:52:14,249] Trial 9 finished with value: 0.33293866403990213 and parameters: {'n_raters': 105}. Best is trial 1 with value: 0.018349138668196208.
#     p_diff=0.055, <class 'float'>
#     n_raters=137, <class 'int'>
#     scores_per_r=38, <class 'int'>
#     total_scores=None, <class 'NoneType'>
#     n_sims=1, <class 'int'>
#     trials_per_sim=120
#     seed=42, <class 'int'>
#     sim_name=power_2_OA055, <class 'str'>
#     chain_method=vectorized, <class 'str'>
#     clean_dir=True, <class 'bool'>
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# [I 2022-11-22 04:24:42,716] Trial 10 finished with value: 0.893817876022097 and parameters: {'n_raters': 137}. Best is trial 1 with value: 0.018349138668196208.
#     p_diff=0.055, <class 'float'>
#     n_raters=159, <class 'int'>
#     scores_per_r=38, <class 'int'>
#     total_scores=None, <class 'NoneType'>
#     n_sims=1, <class 'int'>
#     trials_per_sim=120
#     seed=42, <class 'int'>
#     sim_name=power_2_OA055, <class 'str'>
#     chain_method=vectorized, <class 'str'>
#     clean_dir=True, <class 'bool'>
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# ...
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# [I 2022-11-23 16:02:42,029] Trial 66 finished with value: 0.33293866403990213 and parameters: {'n_raters': 108}. Best is trial 1 with value: 0.018349138668196208.
#     p_diff=0.055, <class 'float'>
#     n_raters=64, <class 'int'>
#     scores_per_r=38, <class 'int'>
#     total_scores=None, <class 'NoneType'>
#     n_sims=1, <class 'int'>
#     trials_per_sim=120
#     seed=42, <class 'int'>
#     sim_name=power_2_OA055, <class 'str'>
#     chain_method=vectorized, <class 'str'>
#     clean_dir=True, <class 'bool'>
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# rm: cannot remove 'data/power_2_OA055/process_5_running': No such file or directory
# rm: cannot remove 'data/power_2_OA055/process_2_running': No such file or directory
# [I 2022-11-23 16:57:43,120] Trial 67 finished with value: 0.11441035117774412 and parameters: {'n_raters': 64}. Best is trial 1 with value: 0.018349138668196208.
#     p_diff=0.055, <class 'float'>
#     n_raters=90, <class 'int'>
#     scores_per_r=38, <class 'int'>
#     total_scores=None, <class 'NoneType'>
#     n_sims=1, <class 'int'>
#     trials_per_sim=120
#     seed=42, <class 'int'>
#     sim_name=power_2_OA055, <class 'str'>
#     chain_method=vectorized, <class 'str'>
#     clean_dir=True, <class 'bool'>
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# [I 2022-11-23 17:42:11,057] Trial 68 finished with value: 0.1541506798272585 and parameters: {'n_raters': 90}. Best is trial 1 with value: 0.018349138668196208.
#     p_diff=0.055, <class 'float'>
#     n_raters=97, <class 'int'>
#     scores_per_r=38, <class 'int'>
#     total_scores=None, <class 'NoneType'>
#     n_sims=1, <class 'int'>
#     trials_per_sim=120
#     seed=42, <class 'int'>
#     sim_name=power_2_OA055, <class 'str'>
#     chain_method=vectorized, <class 'str'>
#     clean_dir=True, <class 'bool'>
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# rm: cannot remove 'data/power_2_OA055/process_0_running': No such file or directory
# rm: cannot remove 'data/power_2_OA055/process_3_running': No such file or directory
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# rm: cannot remove 'data/power_2_OA055/process_5_running': No such file or directory
# [I 2022-11-23 18:43:52,774] Trial 69 finished with value: 0.07082605256861285 and parameters: {'n_raters': 97}. Best is trial 1 with value: 0.018349138668196208.

# %%
sim_name = "power_2_OA070"
OA = True

power_id, p_diff = 0, 0.070
# for power_id, p_diff in enumerate(np.geomspace(0.02, 0.2, num=10)):
# list is used so that sim_id can be incremented in objective func  
sim_id = [0]
study = optuna.create_study(direction="minimize")
study.optimize(objective, n_trials=n_sims)
df = pd.DataFrame([[power_id, p_diff, study.best_trial.number,
                  study.best_params["n_raters"]]],
                  columns=["power_id", "p_diff", "best_trial", "n_raters"]) # Join power when all is complete
if power_id == 0:
    df.to_csv(f"data/simulations/optuna_log_{sim_name}.csv", index=False)
else:
    log=pd.read_csv(f"data/simulations/optuna_log_{sim_name}.csv")
    pd.concat([log, df]).to_csv(f"data/simulations/optuna_log_{sim_name}.csv", index=False)
# Out:
# [I 2022-11-23 18:43:52,913] A new study created in memory with name: no-name-60782a5d-40d2-4d57-934f-59900fed6230
#     p_diff=0.07, <class 'float'>
#     n_raters=105, <class 'int'>
#     scores_per_r=38, <class 'int'>
#     total_scores=None, <class 'NoneType'>
#     n_sims=1, <class 'int'>
#     trials_per_sim=120
#     seed=42, <class 'int'>
#     sim_name=power_2_OA070, <class 'str'>
#     chain_method=vectorized, <class 'str'>
#     clean_dir=True, <class 'bool'>
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# [I 2022-11-23 19:00:10,681] Trial 0 finished with value: 1.5639755383573437 and parameters: {'n_raters': 105}. Best is trial 0 with value: 1.5639755383573437.
#     p_diff=0.07, <class 'float'>
#     n_raters=59, <class 'int'>
#     scores_per_r=38, <class 'int'>
#     total_scores=None, <class 'NoneType'>
#     n_sims=1, <class 'int'>
#     trials_per_sim=120
#     seed=42, <class 'int'>
#     sim_name=power_2_OA070, <class 'str'>
#     chain_method=vectorized, <class 'str'>
#     clean_dir=True, <class 'bool'>
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# [I 2022-11-23 19:44:51,779] Trial 1 finished with value: 0.11441035117774412 and parameters: {'n_raters': 59}. Best is trial 1 with value: 0.11441035117774412.
#     p_diff=0.07, <class 'float'>
#     n_raters=146, <class 'int'>
#     scores_per_r=38, <class 'int'>
#     total_scores=None, <class 'NoneType'>
#     n_sims=1, <class 'int'>
#     trials_per_sim=120
#     seed=42, <class 'int'>
#     sim_name=power_2_OA070, <class 'str'>
#     chain_method=vectorized, <class 'str'>
#     clean_dir=True, <class 'bool'>
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# [I 2022-11-23 20:01:17,444] Trial 2 finished with value: 1.5639755383573437 and parameters: {'n_raters': 146}. Best is trial 1 with value: 0.11441035117774412.
#     p_diff=0.07, <class 'float'>
#     n_raters=34, <class 'int'>
#     scores_per_r=38, <class 'int'>
#     total_scores=None, <class 'NoneType'>
#     n_sims=1, <class 'int'>
#     trials_per_sim=120
#     seed=42, <class 'int'>
#     sim_name=power_2_OA070, <class 'str'>
#     chain_method=vectorized, <class 'str'>
#     clean_dir=True, <class 'bool'>
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# [I 2022-11-23 20:13:36,270] Trial 3 finished with value: 0.8472978603872041 and parameters: {'n_raters': 34}. Best is trial 1 with value: 0.11441035117774412.
#     p_diff=0.07, <class 'float'>
#     n_raters=136, <class 'int'>
#     scores_per_r=38, <class 'int'>
#     total_scores=None, <class 'NoneType'>
#     n_sims=1, <class 'int'>
#     trials_per_sim=120
#     seed=42, <class 'int'>
#     sim_name=power_2_OA070, <class 'str'>
#     chain_method=vectorized, <class 'str'>
#     clean_dir=True, <class 'bool'>
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# [I 2022-11-23 20:29:37,270] Trial 4 finished with value: 1.5639755383573437 and parameters: {'n_raters': 136}. Best is trial 1 with value: 0.11441035117774412.
#     p_diff=0.07, <class 'float'>
#     n_raters=124, <class 'int'>
#     scores_per_r=38, <class 'int'>
#     total_scores=None, <class 'NoneType'>
#     n_sims=1, <class 'int'>
#     trials_per_sim=120
#     seed=42, <class 'int'>
#     sim_name=power_2_OA070, <class 'str'>
#     chain_method=vectorized, <class 'str'>
#     clean_dir=True, <class 'bool'>
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# [I 2022-11-23 20:46:09,095] Trial 5 finished with value: 1.5639755383573437 and parameters: {'n_raters': 124}. Best is trial 1 with value: 0.11441035117774412.
#     p_diff=0.07, <class 'float'>
#     n_raters=57, <class 'int'>
#     scores_per_r=38, <class 'int'>
#     total_scores=None, <class 'NoneType'>
#     n_sims=1, <class 'int'>
#     trials_per_sim=120
#     seed=42, <class 'int'>
#     sim_name=power_2_OA070, <class 'str'>
#     chain_method=vectorized, <class 'str'>
#     clean_dir=True, <class 'bool'>
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# [I 2022-11-23 21:32:29,330] Trial 6 finished with value: 0.4595323293784408 and parameters: {'n_raters': 57}. Best is trial 1 with value: 0.11441035117774412.
#     p_diff=0.07, <class 'float'>
#     n_raters=83, <class 'int'>
#     scores_per_r=38, <class 'int'>
#     total_scores=None, <class 'NoneType'>
#     n_sims=1, <class 'int'>
#     trials_per_sim=120
#     seed=42, <class 'int'>
#     sim_name=power_2_OA070, <class 'str'>
#     chain_method=vectorized, <class 'str'>
#     clean_dir=True, <class 'bool'>
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# [I 2022-11-23 22:03:10,013] Trial 7 finished with value: 0.7731898882334804 and parameters: {'n_raters': 83}. Best is trial 1 with value: 0.11441035117774412.
#     p_diff=0.07, <class 'float'>
#     n_raters=34, <class 'int'>
#     scores_per_r=38, <class 'int'>
#     total_scores=None, <class 'NoneType'>
#     n_sims=1, <class 'int'>
#     trials_per_sim=120
#     seed=42, <class 'int'>
#     sim_name=power_2_OA070, <class 'str'>
#     chain_method=vectorized, <class 'str'>
#     clean_dir=True, <class 'bool'>
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# [I 2022-11-23 22:25:45,883] Trial 8 finished with value: 0.8472978603872041 and parameters: {'n_raters': 34}. Best is trial 1 with value: 0.11441035117774412.
#     p_diff=0.07, <class 'float'>
#     n_raters=69, <class 'int'>
#     scores_per_r=38, <class 'int'>
#     total_scores=None, <class 'NoneType'>
#     n_sims=1, <class 'int'>
#     trials_per_sim=120
#     seed=42, <class 'int'>
#     sim_name=power_2_OA070, <class 'str'>
#     chain_method=vectorized, <class 'str'>
#     clean_dir=True, <class 'bool'>
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# [I 2022-11-23 23:10:42,914] Trial 9 finished with value: 0.7646061445420891 and parameters: {'n_raters': 69}. Best is trial 1 with value: 0.11441035117774412.
#     p_diff=0.07, <class 'float'>
#     n_raters=194, <class 'int'>
#     scores_per_r=38, <class 'int'>
#     total_scores=None, <class 'NoneType'>
#     n_sims=1, <class 'int'>
#     trials_per_sim=120
#     seed=42, <class 'int'>
#     sim_name=power_2_OA070, <class 'str'>
#     chain_method=vectorized, <class 'str'>
#     clean_dir=True, <class 'bool'>
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# [I 2022-11-23 23:28:04,908] Trial 10 finished with value: 1.5639755383573437 and parameters: {'n_raters': 194}. Best is trial 1 with value: 0.11441035117774412.
#     p_diff=0.07, <class 'float'>
#     n_raters=69, <class 'int'>
#     scores_per_r=38, <class 'int'>
#     total_scores=None, <class 'NoneType'>
#     n_sims=1, <class 'int'>
#     trials_per_sim=120
#     seed=42, <class 'int'>
#     sim_name=power_2_OA070, <class 'str'>
#     chain_method=vectorized, <class 'str'>
#     clean_dir=True, <class 'bool'>
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# [I 2022-11-24 00:14:40,903] Trial 11 finished with value: 0.7646061445420891 and parameters: {'n_raters': 69}. Best is trial 1 with value: 0.11441035117774412.
#     p_diff=0.07, <class 'float'>
#     n_raters=53, <class 'int'>
#     scores_per_r=38, <class 'int'>
#     total_scores=None, <class 'NoneType'>
#     n_sims=1, <class 'int'>
#     trials_per_sim=120
#     seed=42, <class 'int'>
#     sim_name=power_2_OA070, <class 'str'>
#     chain_method=vectorized, <class 'str'>
#     clean_dir=True, <class 'bool'>
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# [I 2022-11-24 00:59:54,233] Trial 12 finished with value: 0.1541506798272585 and parameters: {'n_raters': 53}. Best is trial 1 with value: 0.11441035117774412.
#     p_diff=0.07, <class 'float'>
#     n_raters=99, <class 'int'>
#     scores_per_r=38, <class 'int'>
#     total_scores=None, <class 'NoneType'>
#     n_sims=1, <class 'int'>
#     trials_per_sim=120
#     seed=42, <class 'int'>
#     sim_name=power_2_OA070, <class 'str'>
#     chain_method=vectorized, <class 'str'>
#     clean_dir=True, <class 'bool'>
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# ...
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# [I 2022-11-25 05:53:43,923] Trial 62 finished with value: 0.4595323293784408 and parameters: {'n_raters': 57}. Best is trial 1 with value: 0.11441035117774412.
#     p_diff=0.07, <class 'float'>
#     n_raters=49, <class 'int'>
#     scores_per_r=38, <class 'int'>
#     total_scores=None, <class 'NoneType'>
#     n_sims=1, <class 'int'>
#     trials_per_sim=120
#     seed=42, <class 'int'>
#     sim_name=power_2_OA070, <class 'str'>
#     chain_method=vectorized, <class 'str'>
#     clean_dir=True, <class 'bool'>
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# rm: cannot remove 'data/power_2_OA070/process_4_running': No such file or directory
# [I 2022-11-25 06:37:14,139] Trial 63 finished with value: 0.1541506798272585 and parameters: {'n_raters': 49}. Best is trial 1 with value: 0.11441035117774412.
#     p_diff=0.07, <class 'float'>
#     n_raters=31, <class 'int'>
#     scores_per_r=38, <class 'int'>
#     total_scores=None, <class 'NoneType'>
#     n_sims=1, <class 'int'>
#     trials_per_sim=120
#     seed=42, <class 'int'>
#     sim_name=power_2_OA070, <class 'str'>
#     chain_method=vectorized, <class 'str'>
#     clean_dir=True, <class 'bool'>
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# [I 2022-11-25 06:42:54,681] Trial 64 finished with value: 1.2809338454620645 and parameters: {'n_raters': 31}. Best is trial 1 with value: 0.11441035117774412.
#     p_diff=0.07, <class 'float'>
#     n_raters=80, <class 'int'>
#     scores_per_r=38, <class 'int'>
#     total_scores=None, <class 'NoneType'>
#     n_sims=1, <class 'int'>
#     trials_per_sim=120
#     seed=42, <class 'int'>
#     sim_name=power_2_OA070, <class 'str'>
#     chain_method=vectorized, <class 'str'>
#     clean_dir=True, <class 'bool'>
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# [I 2022-11-25 07:34:16,696] Trial 65 finished with value: 0.4595323293784408 and parameters: {'n_raters': 80}. Best is trial 1 with value: 0.11441035117774412.
#     p_diff=0.07, <class 'float'>
#     n_raters=66, <class 'int'>
#     scores_per_r=38, <class 'int'>
#     total_scores=None, <class 'NoneType'>
#     n_sims=1, <class 'int'>
#     trials_per_sim=120
#     seed=42, <class 'int'>
#     sim_name=power_2_OA070, <class 'str'>
#     chain_method=vectorized, <class 'str'>
#     clean_dir=True, <class 'bool'>
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.
# # Option “--command” is deprecated and might be removed in a later version of gnome-terminal.
# # Use “-- ” to terminate the options and put the command line to execute after it.

# %%
print(datetime.now())
