# %%
import numpy as np
import pandas as pd
from scipy.stats import bernoulli
from matplotlib import pyplot as plt

# %%
hoyle_data = pd.read_csv("data/hoyle_automated_2021.csv", header=0)
hoyle_data.head(5).T
# Looks like a wide file of human ratings. Automatic coherence measures 
# should have 1 unique value per dataset/model/topic_idx
# Out:
#                                 0         1         2         3         4
# dataset                  wikitext  wikitext  wikitext  wikitext  wikitext
# model                      mallet    mallet    mallet    mallet    mallet
# topic_idx                       0         0         0         0         0
# human_idx                       0         1         2         3         4
# c_npmi_10_full           0.098871  0.098871  0.098871  0.098871  0.098871
# c_npmi_10_nytimes_full   0.089354  0.089354  0.089354  0.089354  0.089354
# c_npmi_10_test            0.09923   0.09923   0.09923   0.09923   0.09923
# c_npmi_10_train          0.092744  0.092744  0.092744  0.092744  0.092744
# c_npmi_10_val            0.038283  0.038283  0.038283  0.038283  0.038283
# c_uci_full               0.912214  0.912214  0.912214  0.912214  0.912214
# c_v_full                 0.614773  0.614773  0.614773  0.614773  0.614773
# c_v_nytimes_full         0.586538  0.586538  0.586538  0.586538  0.586538
# c_v_test                 0.617187  0.617187  0.617187  0.617187  0.617187
# c_v_train                0.612897  0.612897  0.612897  0.612897  0.612897
# c_v_val                  0.546436  0.546436  0.546436  0.546436  0.546436
# u_mass_full             -2.080614 -2.080614 -2.080614 -2.080614 -2.080614
# scores_raw                      2         3         1         3         3
# confidences_raw                 1         1         1         1         1
# c_npmi_10_wikitext_full       NaN       NaN       NaN       NaN       NaN
# c_v_wikitext_full             NaN       NaN       NaN       NaN       NaN
# task                      ratings   ratings   ratings   ratings   ratings

# %%
# Checking uniqueness of automatic measure for each dataset/model/topic_idx
# Spoiler: it's unique
measures = [c for c in hoyle_data.columns if c[:2] == "c_"] + ["u_mass_full"]
measure_cnt = hoyle_data.groupby(["dataset", "model", "topic_idx"]).agg({measure:"nunique" for measure in measures})
for c in measure_cnt:
    print(f"{c} : {measure_cnt[c].max()}")
# Out:
# c_npmi_10_full : 1
# c_npmi_10_nytimes_full : 1
# c_npmi_10_test : 1
# c_npmi_10_train : 1
# c_npmi_10_val : 1
# c_uci_full : 1
# c_v_full : 1
# c_v_nytimes_full : 1
# c_v_test : 1
# c_v_train : 1
# c_v_val : 1
# c_npmi_10_wikitext_full : 1
# c_v_wikitext_full : 1
# u_mass_full : 1

# %%
# Removing automated measures
hoyle_data = hoyle_data.drop(columns = [c for c in hoyle_data.columns if c[:2] == "c_"] + ["u_mass_full"])
hoyle_data.head(5).T
# Out:
#                         0         1         2         3         4
# dataset          wikitext  wikitext  wikitext  wikitext  wikitext
# model              mallet    mallet    mallet    mallet    mallet
# topic_idx               0         0         0         0         0
# human_idx               0         1         2         3         4
# scores_raw              2         3         1         3         3
# confidences_raw         1         1         1         1         1
# task              ratings   ratings   ratings   ratings   ratings

# %%
# Checking if measure ranges are as expected.
# Spoiler: They are.
print(hoyle_data[hoyle_data["task"]=="intrusions"]["scores_raw"].value_counts())
print(hoyle_data[hoyle_data["task"]=="ratings"]["scores_raw"].value_counts())
# Out:
# 1    5555
# 0    2245
# Name: scores_raw, dtype: int64
# 3    2761
# 2    1318
# 1     421
# Name: scores_raw, dtype: int64

# %%
hoyle_data.groupby("topic_idx").agg({"scores_raw":["sum"], "confidences_raw":["sum"]})
# Out:
#           scores_raw confidences_raw
#                  sum             sum
# topic_idx
# 0                305             212
# 1                361             204
# 2                349             226
# 3                337             228
# 4                320             217
# 5                302             240
# 6                367             239
# 7                315             227
# 8                310             219
# 9                370             241
# 10               312             236
# 11               348             230
# 12               362             243
# 13               372             228
# 14               367             225
# 15               341             235
# 16               343             210
# 17               312             212
# 18               316             193
# 19               332             235
# 20               349             197
# 21               340             233
# 22               319             219
# 23               346             227
# 24               390             242
# 25               357             228
# 26               374             220
# 27               308             214
# 28               316             230
# 29               338             212
# 30               279             207
# 31               329             229
# 32               357             208
# 33               317             204
# 34               336             233
# 35               373             237
# 36               352             233
# 37               316             243
# 38               328             199
# 39               350             215
# 40               341             237
# 41               370             217
# 42               312             210
# 43               301             232
# 44               318             214
# 45               319             219
# 46               324             219
# 47               389             242
# 48               333             215
# 49               373             238

# %%
test = hoyle_data[(hoyle_data["task"]=="intrusions") & (hoyle_data["topic_idx"]==0)]

# %%
test[test["human_idx"]==0]
# Out:
#         dataset   model  topic_idx  human_idx  scores_raw  confidences_raw  \
# 4500   wikitext  mallet          0          0           1                1
# 5800   wikitext    dvae          0          0           0                0
# 7100   wikitext     etm          0          0           0                1
# 8400    nytimes  mallet          0          0           1                1
# 9700    nytimes    dvae          0          0           0                1
# 11000   nytimes     etm          0          0           1                1
#
#              task
# 4500   intrusions
# 5800   intrusions
# 7100   intrusions
# 8400   intrusions
# 9700   intrusions
# 11000  intrusions
